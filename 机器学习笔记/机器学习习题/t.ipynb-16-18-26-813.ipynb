# %%
import os
import re
from urllib.parse import urlparse

def extract_images_from_md(file_path):
    """从单个md文件中提取所有图片链接"""
    images = []
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()
        
        # 匹配Markdown格式的图片链接: ![alt text](image_url)
        # 支持普通格式和带title的格式
        pattern = r'!\[([^\]]*)\]\(([^)]+)\)'
        matches = re.findall(pattern, content)
        
        for alt_text, image_url in matches:
            # 去除可能的title部分
            image_url = image_url.split('"')[0].split("'")[0]
            images.append({
                'alt_text': alt_text,
                'image_url': image_url,
                'file_path': file_path
            })
            
        # 匹配HTML格式的图片: <img src="...">
        html_pattern = r'<img[^>]+src=["\']([^"\']+)["\'][^>]*>'
        html_matches = re.findall(html_pattern, content, re.IGNORECASE)
        
        for image_url in html_matches:
            images.append({
                'alt_text': '',
                'image_url': image_url,
                'file_path': file_path
            })
            
    except Exception as e:
        print(f"读取文件 {file_path} 时出错: {e}")
    
    return images

def find_md_files(directory):
    """查找目录下所有.md文件"""
    md_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith('.md'):
                md_files.append(os.path.join(root, file))
    return md_files

def main():
    """主函数"""
    current_directory = os.getcwd()
    print(f"正在扫描目录: {current_directory}")
    
    # 获取所有.md文件
    md_files = find_md_files(current_directory)
    print(f"找到 {len(md_files)} 个Markdown文件")
    
    all_images = []
    
    # 遍历每个.md文件，提取图片链接
    for md_file in md_files:
        print(f"\n正在处理: {md_file}")
        images = extract_images_from_md(md_file)
        
        if images:
            print(f"  找到 {len(images)} 个图片链接:")
            for img in images:
                print(f"    - {img['image_url']}")
                if img['alt_text']:
                    print(f"      (alt: {img['alt_text']})")
            all_images.extend(images)
        else:
            print("  未找到图片链接")
    
    print(f"\n总共找到 {len(all_images)} 个图片链接")
    
    # 按文件路径和图片URL分组显示结果
    if all_images:
        print("\n详细列表:")
        for i, img in enumerate(all_images, 1):
            print(f"{i}. 文件: {img['file_path']}")
            print(f"   图片: {img['image_url']}")
            if img['alt_text']:
                print(f"   描述: {img['alt_text']}")
            print()
    
    # 统计不同类型的图片链接
    local_images = [img for img in all_images if not img['image_url'].startswith(('http://', 'https://'))]
    remote_images = [img for img in all_images if img['image_url'].startswith(('http://', 'https://'))]
    

    return local_images

# %%
result = main()
# Out:
# 正在扫描目录: /Users/wangxujie/Downloads/_posts/机器学习习题
# 找到 8 个Markdown文件
#
# 正在处理: /Users/wangxujie/Downloads/_posts/机器学习习题/ex3-neural network.md
#   找到 3 个图片链接:
#     - Figure_1.png
#       (alt: image)
#     - Figure_2.png
#       (alt: image)
#     - Figure_3.jpg
#       (alt: image)
#
# 正在处理: /Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md
#   找到 4 个图片链接:
#     - Figure_1.png
#       (alt: image)
#     - Figure_2.png
#       (alt: image)
#     - Figure_3.png
#       (alt: image)
#     - Figure_4.png
#       (alt: image)
#
# 正在处理: /Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md
#   找到 5 个图片链接:
#     - Figure_1.png
#       (alt: image)
#     - Figure_1-1.png
#       (alt: image)
#     - Figure_1-2.png
#       (alt: image)
#     - Figure_1-3.png
#       (alt: image)
#     - Figure_1-4.png
#       (alt: image)
#
# 正在处理: /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md
#   找到 7 个图片链接:
#     - Figure_1.png
#       (alt: image)
#     - Figure_2.jpg
#       (alt: image)
#     - Figure_4
#       (alt: image)
#     - Figure_5
#       (alt: image)
#     - Figure_7.png
#       (alt: image)
#     - Figure_6.png
#       (alt: image)
#     - Figure_3.png
#       (alt: image)
#
# 正在处理: /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md
#   找到 8 个图片链接:
#     - Figure_1.png
#       (alt: image)
#     - Figure_3.png
#       (alt: image)
#     - Figure_2.png
#       (alt: image)
#     - Figure_4.png
#       (alt: image)
#     - Figure_5.png
#       (alt: image)
#     - Figure_6.png
#       (alt: image)
#     - Figure_7.png
#       (alt: image)
#     - Figure_8.png
#       (alt: image)
#
# 正在处理: /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md
#   找到 6 个图片链接:
#     - Figure_1.png
#       (alt: image)
#     - Figure_2.png
#       (alt: image)
#     - Figure_3.png
#       (alt: image)
#     - Figure_5.png
#       (alt: image)
#     - Figure_6.png
#       (alt: image)
#     - Figure_7.png
#       (alt: image)
#
# 正在处理: /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md
#   找到 6 个图片链接:
#     - Figure_1.png
#       (alt: image)
#     - Figure_2.png
#       (alt: image)
#     - bird_small.png
#       (alt: image)
#     - Figure_3.png
#       (alt: image)
#     - Figure_4.png
#       (alt: image)
#     - Figure_5.png
#       (alt: image)
#
# 正在处理: /Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md
#   找到 4 个图片链接:
#     - rcmd_cost.png
#       (alt: Cost)
#     - rcmd_gradient.png
#       (alt: Gradient)
#     - rcmd_vectorized_grad.png
#       (alt: Gradient)
#     - rcmd_reg_gradient.png
#       (alt: Gradient)
#
# 总共找到 43 个图片链接
#
# 详细列表:
# 1. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex3-neural network.md
#    图片: Figure_1.png
#    描述: image
#
# 2. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex3-neural network.md
#    图片: Figure_2.png
#    描述: image
#
# 3. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex3-neural network.md
#    图片: Figure_3.jpg
#    描述: image
#
# 4. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md
#    图片: Figure_1.png
#    描述: image
#
# 5. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md
#    图片: Figure_2.png
#    描述: image
#
# 6. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md
#    图片: Figure_3.png
#    描述: image
#
# 7. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md
#    图片: Figure_4.png
#    描述: image
#
# 8. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md
#    图片: Figure_1.png
#    描述: image
#
# 9. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md
#    图片: Figure_1-1.png
#    描述: image
#
# 10. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md
#    图片: Figure_1-2.png
#    描述: image
#
# 11. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md
#    图片: Figure_1-3.png
#    描述: image
#
# 12. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md
#    图片: Figure_1-4.png
#    描述: image
#
# 13. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md
#    图片: Figure_1.png
#    描述: image
#
# 14. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md
#    图片: Figure_2.jpg
#    描述: image
#
# 15. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md
#    图片: Figure_4
#    描述: image
#
# 16. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md
#    图片: Figure_5
#    描述: image
#
# 17. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md
#    图片: Figure_7.png
#    描述: image
#
# 18. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md
#    图片: Figure_6.png
#    描述: image
#
# 19. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md
#    图片: Figure_3.png
#    描述: image
#
# 20. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md
#    图片: Figure_1.png
#    描述: image
#
# 21. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md
#    图片: Figure_3.png
#    描述: image
#
# 22. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md
#    图片: Figure_2.png
#    描述: image
#
# 23. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md
#    图片: Figure_4.png
#    描述: image
#
# 24. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md
#    图片: Figure_5.png
#    描述: image
#
# 25. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md
#    图片: Figure_6.png
#    描述: image
#
# 26. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md
#    图片: Figure_7.png
#    描述: image
#
# 27. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md
#    图片: Figure_8.png
#    描述: image
#
# 28. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md
#    图片: Figure_1.png
#    描述: image
#
# 29. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md
#    图片: Figure_2.png
#    描述: image
#
# 30. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md
#    图片: Figure_3.png
#    描述: image
#
# 31. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md
#    图片: Figure_5.png
#    描述: image
#
# 32. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md
#    图片: Figure_6.png
#    描述: image
#
# 33. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md
#    图片: Figure_7.png
#    描述: image
#
# 34. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md
#    图片: Figure_1.png
#    描述: image
#
# 35. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md
#    图片: Figure_2.png
#    描述: image
#
# 36. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md
#    图片: bird_small.png
#    描述: image
#
# 37. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md
#    图片: Figure_3.png
#    描述: image
#
# 38. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md
#    图片: Figure_4.png
#    描述: image
#
# 39. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md
#    图片: Figure_5.png
#    描述: image
#
# 40. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md
#    图片: rcmd_cost.png
#    描述: Cost
#
# 41. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md
#    图片: rcmd_gradient.png
#    描述: Gradient
#
# 42. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md
#    图片: rcmd_vectorized_grad.png
#    描述: Gradient
#
# 43. 文件: /Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md
#    图片: rcmd_reg_gradient.png
#    描述: Gradient

# %%
from collections import Counter

def get_new_file_name(item, counter):
    file_name = item["file_path"].split('/')[-1].split('.')[0]
    img_suffix = item["image_url"].split('.')[-1]
    counter.update([file_name])
    new_name = file_name + "_" + str(counter[file_name]) + "." + img_suffix

    return new_name

# %%
counter = Counter()
for item in result:
    new_name = get_new_file_name(item, counter)
    item.update({'new_path': new_name})

# %%
result
# Out:
# [{'alt_text': 'image',
#   'image_url': 'Figure_1.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex3-neural network.md',
#   'new_name': 'ex3-neural network_1.png',
#   'new_path': 'ex3-neural network_1.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_2.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex3-neural network.md',
#   'new_name': 'ex3-neural network_2.png',
#   'new_path': 'ex3-neural network_2.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_3.jpg',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex3-neural network.md',
#   'new_name': 'ex3-neural network_3.jpg',
#   'new_path': 'ex3-neural network_3.jpg'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_1.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md',
#   'new_name': 'ex1-linear regression_1.png',
#   'new_path': 'ex1-linear regression_1.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_2.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md',
#   'new_name': 'ex1-linear regression_2.png',
#   'new_path': 'ex1-linear regression_2.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_3.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md',
#   'new_name': 'ex1-linear regression_3.png',
#   'new_path': 'ex1-linear regression_3.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_4.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md',
#   'new_name': 'ex1-linear regression_4.png',
#   'new_path': 'ex1-linear regression_4.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_1.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md',
#   'new_name': 'ex6-SVM_1.png',
#   'new_path': 'ex6-SVM_1.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_1-1.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md',
#   'new_name': 'ex6-SVM_2.png',
#   'new_path': 'ex6-SVM_2.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_1-2.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md',
#   'new_name': 'ex6-SVM_3.png',
#   'new_path': 'ex6-SVM_3.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_1-3.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md',
#   'new_name': 'ex6-SVM_4.png',
#   'new_path': 'ex6-SVM_4.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_1-4.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md',
#   'new_name': 'ex6-SVM_5.png',
#   'new_path': 'ex6-SVM_5.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_1.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md',
#   'new_name': 'ex4-NN back propagation_1.png',
#   'new_path': 'ex4-NN back propagation_1.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_2.jpg',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md',
#   'new_name': 'ex4-NN back propagation_2.jpg',
#   'new_path': 'ex4-NN back propagation_2.jpg'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_4',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md',
#   'new_name': 'ex4-NN back propagation_3.Figure_4',
#   'new_path': 'ex4-NN back propagation_3.Figure_4'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_5',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md',
#   'new_name': 'ex4-NN back propagation_4.Figure_5',
#   'new_path': 'ex4-NN back propagation_4.Figure_5'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_7.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md',
#   'new_name': 'ex4-NN back propagation_5.png',
#   'new_path': 'ex4-NN back propagation_5.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_6.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md',
#   'new_name': 'ex4-NN back propagation_6.png',
#   'new_path': 'ex4-NN back propagation_6.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_3.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md',
#   'new_name': 'ex4-NN back propagation_7.png',
#   'new_path': 'ex4-NN back propagation_7.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_1.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md',
#   'new_name': 'ex5-bias vs variance_1.png',
#   'new_path': 'ex5-bias vs variance_1.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_3.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md',
#   'new_name': 'ex5-bias vs variance_2.png',
#   'new_path': 'ex5-bias vs variance_2.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_2.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md',
#   'new_name': 'ex5-bias vs variance_3.png',
#   'new_path': 'ex5-bias vs variance_3.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_4.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md',
#   'new_name': 'ex5-bias vs variance_4.png',
#   'new_path': 'ex5-bias vs variance_4.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_5.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md',
#   'new_name': 'ex5-bias vs variance_5.png',
#   'new_path': 'ex5-bias vs variance_5.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_6.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md',
#   'new_name': 'ex5-bias vs variance_6.png',
#   'new_path': 'ex5-bias vs variance_6.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_7.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md',
#   'new_name': 'ex5-bias vs variance_7.png',
#   'new_path': 'ex5-bias vs variance_7.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_8.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md',
#   'new_name': 'ex5-bias vs variance_8.png',
#   'new_path': 'ex5-bias vs variance_8.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_1.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md',
#   'new_name': 'ex2-logistic regression_1.png',
#   'new_path': 'ex2-logistic regression_1.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_2.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md',
#   'new_name': 'ex2-logistic regression_2.png',
#   'new_path': 'ex2-logistic regression_2.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_3.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md',
#   'new_name': 'ex2-logistic regression_3.png',
#   'new_path': 'ex2-logistic regression_3.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_5.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md',
#   'new_name': 'ex2-logistic regression_4.png',
#   'new_path': 'ex2-logistic regression_4.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_6.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md',
#   'new_name': 'ex2-logistic regression_5.png',
#   'new_path': 'ex2-logistic regression_5.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_7.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md',
#   'new_name': 'ex2-logistic regression_6.png',
#   'new_path': 'ex2-logistic regression_6.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_1.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md',
#   'new_name': 'ex7-k means and PCA_1.png',
#   'new_path': 'ex7-k means and PCA_1.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_2.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md',
#   'new_name': 'ex7-k means and PCA_2.png',
#   'new_path': 'ex7-k means and PCA_2.png'},
#  {'alt_text': 'image',
#   'image_url': 'bird_small.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md',
#   'new_name': 'ex7-k means and PCA_3.png',
#   'new_path': 'ex7-k means and PCA_3.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_3.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md',
#   'new_name': 'ex7-k means and PCA_4.png',
#   'new_path': 'ex7-k means and PCA_4.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_4.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md',
#   'new_name': 'ex7-k means and PCA_5.png',
#   'new_path': 'ex7-k means and PCA_5.png'},
#  {'alt_text': 'image',
#   'image_url': 'Figure_5.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md',
#   'new_name': 'ex7-k means and PCA_6.png',
#   'new_path': 'ex7-k means and PCA_6.png'},
#  {'alt_text': 'Cost',
#   'image_url': 'rcmd_cost.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md',
#   'new_name': 'ex8-anomaly detection and recommendation_1.png',
#   'new_path': 'ex8-anomaly detection and recommendation_1.png'},
#  {'alt_text': 'Gradient',
#   'image_url': 'rcmd_gradient.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md',
#   'new_name': 'ex8-anomaly detection and recommendation_2.png',
#   'new_path': 'ex8-anomaly detection and recommendation_2.png'},
#  {'alt_text': 'Gradient',
#   'image_url': 'rcmd_vectorized_grad.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md',
#   'new_name': 'ex8-anomaly detection and recommendation_3.png',
#   'new_path': 'ex8-anomaly detection and recommendation_3.png'},
#  {'alt_text': 'Gradient',
#   'image_url': 'rcmd_reg_gradient.png',
#   'file_path': '/Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md',
#   'new_name': 'ex8-anomaly detection and recommendation_4.png',
#   'new_path': 'ex8-anomaly detection and recommendation_4.png'}]

# %%
import os
import urllib.parse
import re

for item in result:
    file_path = urllib.parse.unquote(item['file_path'])
    image_url = urllib.parse.unquote(item['image_url'])
    new_path = urllib.parse.unquote(item['new_path'])

    if not os.path.exists(file_path):
        print(f"❌ 文件不存在: {file_path}")
        continue

    with open(file_path, "r", encoding="utf-8") as f:
        content = f.read()

    # 原始形式与 URL 编码形式
    encoded_image_url = urllib.parse.quote(image_url)

    # Markdown 图片匹配（防止误替换）
    patterns = [
        rf'!\[.*?\]\((?:\./)?{re.escape(image_url)}\)',
        rf'!\[.*?\]\((?:\./)?{re.escape(encoded_image_url)}\)',
    ]

    replaced = False
    for pattern in patterns:
        if re.search(pattern, content):
            content = re.sub(pattern, f"![]({new_path})", content)
            replaced = True

    if replaced:
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(content)
        print(f"✅ 已更新 {file_path}: {image_url} → {new_path}")
    else:
        print(f"⚠️ 未找到匹配: {image_url} 或 {encoded_image_url} in {file_path}")
# Out:
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex3-neural network.md: Figure_1.png → ex3-neural network_1.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex3-neural network.md: Figure_2.png → ex3-neural network_2.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex3-neural network.md: Figure_3.jpg → ex3-neural network_3.jpg
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md: Figure_1.png → ex1-linear regression_1.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md: Figure_2.png → ex1-linear regression_2.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md: Figure_3.png → ex1-linear regression_3.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex1-linear regression.md: Figure_4.png → ex1-linear regression_4.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md: Figure_1.png → ex6-SVM_1.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md: Figure_1-1.png → ex6-SVM_2.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md: Figure_1-2.png → ex6-SVM_3.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md: Figure_1-3.png → ex6-SVM_4.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex6-SVM.md: Figure_1-4.png → ex6-SVM_5.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md: Figure_1.png → ex4-NN back propagation_1.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md: Figure_2.jpg → ex4-NN back propagation_2.jpg
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md: Figure_4 → ex4-NN back propagation_3.Figure_4
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md: Figure_5 → ex4-NN back propagation_4.Figure_5
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md: Figure_7.png → ex4-NN back propagation_5.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md: Figure_6.png → ex4-NN back propagation_6.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex4-NN back propagation.md: Figure_3.png → ex4-NN back propagation_7.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md: Figure_1.png → ex5-bias vs variance_1.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md: Figure_3.png → ex5-bias vs variance_2.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md: Figure_2.png → ex5-bias vs variance_3.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md: Figure_4.png → ex5-bias vs variance_4.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md: Figure_5.png → ex5-bias vs variance_5.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md: Figure_6.png → ex5-bias vs variance_6.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md: Figure_7.png → ex5-bias vs variance_7.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex5-bias vs variance.md: Figure_8.png → ex5-bias vs variance_8.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md: Figure_1.png → ex2-logistic regression_1.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md: Figure_2.png → ex2-logistic regression_2.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md: Figure_3.png → ex2-logistic regression_3.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md: Figure_5.png → ex2-logistic regression_4.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md: Figure_6.png → ex2-logistic regression_5.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex2-logistic regression.md: Figure_7.png → ex2-logistic regression_6.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md: Figure_1.png → ex7-k means and PCA_1.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md: Figure_2.png → ex7-k means and PCA_2.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md: bird_small.png → ex7-k means and PCA_3.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md: Figure_3.png → ex7-k means and PCA_4.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md: Figure_4.png → ex7-k means and PCA_5.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex7-k means and PCA.md: Figure_5.png → ex7-k means and PCA_6.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md: rcmd_cost.png → ex8-anomaly detection and recommendation_1.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md: rcmd_gradient.png → ex8-anomaly detection and recommendation_2.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md: rcmd_vectorized_grad.png → ex8-anomaly detection and recommendation_3.png
# ✅ 已更新 /Users/wangxujie/Downloads/_posts/机器学习习题/ex8-anomaly detection and recommendation.md: rcmd_reg_gradient.png → ex8-anomaly detection and recommendation_4.png
