# %%
YOUR_INFURA_API_KEY = "9fa694744c3c452988e5622d63037e78"

# %% [markdown]
# # Web3.py 简介 · 面向 Python 开发者的以太坊
#
# 今天，我将带领大家开启 Web3.py 库的使用之旅。倘若你是一名 Python 开发者，那么 Web3.py 将是你与以太坊区块链进行交互的不二之选。在接下来这个由 6 部分构成的系列教程中，我会循序渐进地为你展示如何运用 Web3.py 与以太坊区块链展开交互。
#
# ## 什么是 Web3.py？
#
# 本视频作为系列教程的第一部分（共六部分），将首先对 Web3.py 库进行整体概述，随后演示如何查看以太坊账户的余额。
#
# 利用以太坊开发区块链应用程序，涉及多个不同方面：
#
# 1. **开发智能合约**：运用 Solidity 编程语言编写可在区块链上运行的程序。
# 2. **开发与区块链交互的客户端**：编写用于从区块链读取和写入数据的代码（涵盖与智能合约的交互）。
#
# Web3.py 能够助力你完成第二项任务，即开发与以太坊区块链交互的客户端。这里所说的“客户端”，并非特指面向用户的应用程序（如 Web 应用程序），而是指通过读取区块链信息、写入新的交易数据，或者借助智能合约执行业务逻辑，来与区块链进行交互的“客户端”。鉴于你使用 Python 编写代码，这个“客户端”可能是一个抓取区块链数据的脚本，也可能是执行智能合约函数的服务器进程。Web3.py 是一个库集合，借助它，你可以执行以下操作：创建以太坊交易、从智能合约读取和写入数据、创建智能合约等等！
#
# 下面，让我们一同看看如何使用 Web3.py 与以太坊进行交互（如下图所示）：
# ![](images/web32eth.png)
#
# Web3.py 通过 JSON RPC （远程过程调用）协议与以太坊区块链实现通信。以太坊是一个点对点的节点网络，它将所有数据分布在网络中的每个节点上。也就是说，网络上的每个节点都保存着网络上所有代码和数据的副本。Web3.py 允许我们使用 JSON RPC 代表整个网络向单个以太坊节点发出请求。如此一来，我们便能够通过单个节点读取和写入网络数据。这有点类似于向 Web 服务器上的 JSON API 发出 HTTP 请求。

# %% [markdown]
# ## 依赖项
#
# 让我们着手安装并配置使用 Web3.py 进行开发所需的各项依赖。
#
# ### Python 环境
#
# 首先，请确保你的系统中已安装合适版本的 Python。在本系列教程中，我使用的是 3.6.7 版本。为了更好地管理开发环境，建议你使用环境管理器，如 Python 自带的 `venv` 或 `pyenv`，你可以从官方渠道下载它们。
#
# 要检查你的机器上是否已安装 Python，可以在终端中输入以下命令：
#
# ```bash
# python --version
# ```
#
# 在继续后续操作前，请务必确认已安装 Python 3 版本。如果你的系统中安装了多个 Python 版本，并且需要使用 `python3` 命令来访问 Python 3 版本，那么在本系列教程的所有 Python 终端命令中，都请使用 `python3` 替代 `python`。
#
# 接下来，使用 `venv` 或 `pyenv` 创建一个虚拟环境，用于安装后续的 Python 依赖项。
#
# ### Web3.py 库安装
#
# 在终端中，你可以使用 `pip` 工具来安装 Web3.py 库，命令如下：
#
# ```bash
# pip install web3
# ```
#
# ### Infura RPC URL 配置
#
# 为了通过 JSON RPC 连接到以太坊主网节点，我们需要获取访问以太坊节点的途径。有几种方式可以实现这一目标。其一，你可以使用 Geth 或 Parity 自行运行一个以太坊节点，但这需要你下载大量的区块链数据并保持节点的同步状态。如果你曾尝试过这种方式，就会知道这其中的难度和复杂性。
#
# 更为便捷的方式是，使用 Infura 提供的服务来访问以太坊节点，而无需自己运行节点。Infura 是一项免费的服务，它提供了远程的以太坊节点。你只需注册 Infura 账号，获取 API 密钥以及要连接的网络的 RPC URL 即可。
#
# 注册完成后，你的 Infura RPC URL 格式应如下所示：
#
# ```
# https://mainnet.infura.io/v3/YOUR_INFURA_API_KEY_GOES_HERE
# ```
#
# ## 检查账户余额
#
# 当所有依赖项都安装并配置完成后，你就可以开始使用 Web3.py 进行开发了！首先，在终端中启动 Python shell，命令如下：
#
# 现在，你已经成功打开了 Python shell！在 Python shell 中，你可以按照以下方式导入 Web3.py 库：

# %%
from web3 import Web3

infura_url = f"https://mainnet.infura.io/v3/{YOUR_INFURA_API_KEY}"
web3 = Web3(Web3.HTTPProvider(infura_url))

# %% [markdown]
# 现在，您已经拥有一个实时的 Web3 连接，可以与以太坊主网通信了！我们可以像这样确保连接成功：

# %%
web3.is_connected()
# Out:
# True

# %% [markdown]
# 如果连接有效，则返回 true。接下来，我们可以像这样检查最新的区块号：

# %%
web3.eth.block_number
# Out:
# 23644784

# %% [markdown]
# 这是最新的区块号！现在让我们检查一下这个账户的余额： 0x90e63c3d53E0Ea496845b7a03ec7548B70014A91 。我们可以通过使用 web3.eth.get_balance() 检查余额来了解这个账户持有多少以太币。

# %% [markdown]
# 首先，让我们将地址分配给一个变量：

# %%
account = "0x388C818CA8B9251b393131C08a736A67ccB19297"
balance = web3.eth.get_balance(account)
web3.from_wei(balance, "ether")
# Out:
# Decimal('19.647278378122494711')

# %% [markdown]
# 这就是账户余额！不过，需要注意的是，这个账户余额是以 wei 表示的，wei 是 Ether 的一个分支，类似于一分钱。你必须用 10 ** 18 除以 wei 才能将其转换为 Ether。

# %% [markdown]
# 我还要提一下，通读 Web3.py 文档可以让你全面了解该库的功能。我强烈建议你浏览一下，即使你并不完全了解它的功能。你可以在这里找到 Web3.py 的完整文档：
# https://web3py.readthedocs.io/en/stable/

# %% [markdown]
# 此外，请注意，Web3.py 正在积极开发中。您可以访问 Web3.py 的 GitHub 仓库来跟踪其进展，也可以阅读代码以更好地理解该库本身。您可以在此处找到 GitHub 仓库：
# https://github.com/ethereum/Web3.py/

# %% [markdown]
# # 使用 Web3.py 从智能合约读取数据
#
# 欢迎来到系列教程的第二集。在本集中，我将为大家详细介绍如何使用 Web3.py 从以太坊区块链读取智能合约数据。
#
# 接下来，我们继续导入所需的库，并设置 web3 连接：

# %%
import json
from web3 import Web3

infura_url = f"https://mainnet.infura.io/v3/{YOUR_INFURA_API_KEY}"
web3 = Web3(Web3.HTTPProvider(infura_url))

# %% [markdown]
# 为了使用 Web3.py 从智能合约中读取数据，我们需要以下两个关键要素：
#
# 1. 目标智能合约的 Python 表示
# 2. 调用智能合约函数以读取数据的方法
#
# 我们可以通过 `web3.eth.Contract()` 函数获取以太坊智能合约的 Python 表示。该函数需要两个核心参数：智能合约的 ABI（应用二进制接口）和智能合约地址。
#
# 智能合约 ABI（Application Binary Interface）是一个 JSON 数组，它详细描述了特定智能合约的接口信息和工作方式。以下是一个 ABI 示例：
#
# ```python
# abi = [{"constant":true,"inputs":[],.....],"name":"Transfer","type":"event"}]
# ```
#
# （注：这是一个完整的 ABI 数组示例，结构较为复杂。此示例展示的是 OmiseGo 代币的 ABI，该代币实现了 ERC - 20 代币标准。若您对 ERC - 20 标准不熟悉，可参考相关视频进行了解。您可以在 Etherscan 上查询该代币的详细信息，包括其 ABI 和地址。在本示例的后续部分，我们将使用此智能合约 ABI。）
#
# 在此，我将存储来自以太坊主网的 OMG 代币地址：
#
# ```python
# address = "0xd26114cd6EE289AccF82350c8d8487fedB8A0C07"
# ```
#
# 现在，我们已经获取了 ABI 和地址这两个必要值，接下来就可以创建 OMG 代币智能合约的完整 Python 表示，代码如下：

# %%
address = "0xd26114cd6EE289AccF82350c8d8487fedB8A0C07"
abi = json.loads('[{"constant":true,"inputs":[],"name":"mintingFinished","outputs":[{"name":"","type":"bool"}],"payable":false,"type":"function"},{"constant":true,"inputs":[],"name":"name","outputs":[{"name":"","type":"string"}],"payable":false,"type":"function"},{"constant":false,"inputs":[{"name":"_spender","type":"address"},{"name":"_value","type":"uint256"}],"name":"approve","outputs":[],"payable":false,"type":"function"},{"constant":true,"inputs":[],"name":"totalSupply","outputs":[{"name":"","type":"uint256"}],"payable":false,"type":"function"},{"constant":false,"inputs":[{"name":"_from","type":"address"},{"name":"_to","type":"address"},{"name":"_value","type":"uint256"}],"name":"transferFrom","outputs":[],"payable":false,"type":"function"},{"constant":true,"inputs":[],"name":"decimals","outputs":[{"name":"","type":"uint256"}],"payable":false,"type":"function"},{"constant":false,"inputs":[],"name":"unpause","outputs":[{"name":"","type":"bool"}],"payable":false,"type":"function"},{"constant":false,"inputs":[{"name":"_to","type":"address"},{"name":"_amount","type":"uint256"}],"name":"mint","outputs":[{"name":"","type":"bool"}],"payable":false,"type":"function"},{"constant":true,"inputs":[],"name":"paused","outputs":[{"name":"","type":"bool"}],"payable":false,"type":"function"},{"constant":true,"inputs":[{"name":"_owner","type":"address"}],"name":"balanceOf","outputs":[{"name":"balance","type":"uint256"}],"payable":false,"type":"function"},{"constant":false,"inputs":[],"name":"finishMinting","outputs":[{"name":"","type":"bool"}],"payable":false,"type":"function"},{"constant":false,"inputs":[],"name":"pause","outputs":[{"name":"","type":"bool"}],"payable":false,"type":"function"},{"constant":true,"inputs":[],"name":"owner","outputs":[{"name":"","type":"address"}],"payable":false,"type":"function"},{"constant":true,"inputs":[],"name":"symbol","outputs":[{"name":"","type":"string"}],"payable":false,"type":"function"},{"constant":false,"inputs":[{"name":"_to","type":"address"},{"name":"_value","type":"uint256"}],"name":"transfer","outputs":[],"payable":false,"type":"function"},{"constant":false,"inputs":[{"name":"_to","type":"address"},{"name":"_amount","type":"uint256"},{"name":"_releaseTime","type":"uint256"}],"name":"mintTimelocked","outputs":[{"name":"","type":"address"}],"payable":false,"type":"function"},{"constant":true,"inputs":[{"name":"_owner","type":"address"},{"name":"_spender","type":"address"}],"name":"allowance","outputs":[{"name":"remaining","type":"uint256"}],"payable":false,"type":"function"},{"constant":false,"inputs":[{"name":"newOwner","type":"address"}],"name":"transferOwnership","outputs":[],"payable":false,"type":"function"},{"anonymous":false,"inputs":[{"indexed":true,"name":"to","type":"address"},{"indexed":false,"name":"value","type":"uint256"}],"name":"Mint","type":"event"},{"anonymous":false,"inputs":[],"name":"MintFinished","type":"event"},{"anonymous":false,"inputs":[],"name":"Pause","type":"event"},{"anonymous":false,"inputs":[],"name":"Unpause","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"name":"owner","type":"address"},{"indexed":true,"name":"spender","type":"address"},{"indexed":false,"name":"value","type":"uint256"}],"name":"Approval","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"name":"from","type":"address"},{"indexed":true,"name":"to","type":"address"},{"indexed":false,"name":"value","type":"uint256"}],"name":"Transfer","type":"event"}]')
contract = web3.eth.contract(address=address, abi=abi)
contract

# %% [markdown]
# 既然本课的第一部分已经完成，接下来我们需要完成第二部分：通过调用智能合约的函数来读取数据。所有智能合约函数都列在指定的 Web3 合约的 contract.functions 命名空间下。例如，如果合约实现了 myFunction()，我们可以调用 contract.functions.myFunction()。
#
# 太棒了！理论上，我们可以调用智能合约实现的任何函数。但是，如何才能知道它具体实现了哪些函数呢？首先，我们可以将 contract.functions 记录到控制台，查看返回的内容（你可以在上面的视频中看到我是如何操作的）。不过，由于这个智能合约实现了 ERC - 20 标准，我们已经知道它实现了多个函数，例如 totalSupply()、name()、symbol() 和 balanceOf()。我们可以分别读取这些函数的值，代码如下：

# %% [markdown]
# 首先，所有 OMG 代币的总供应量：

# %%
totalSupply = contract.functions.totalSupply().call()
totalSupply
# Out:
# 140245398245132780789239631

# %%
web3.from_wei(totalSupply, 'ether')
# Out:
# Decimal('140245398.245132780789239631')

# %% [markdown]
# 二、OMG 代币名称：

# %%
contract.functions.name().call()
# Out:
# 'OMGToken'

# %% [markdown]
# 三、OMG 代币的符号：

# %%
contract.functions.symbol().call()
# Out:
# 'OMG'

# %% [markdown]
# 最后，我们可以查看指定账户的余额。我在 Etherscan 上查找了一位 OMG 持有者，找到了这个地址0xd26114cd6EE289AccF82350c8d8487fedB8A0C07 。我们可以像这样查看这个账户的余额：

# %%
balance = contract.functions.balanceOf('0xd26114cd6EE289AccF82350c8d8487fedB8A0C07').call()

# %%
web3.from_wei(balance, 'ether')
# Out:
# Decimal('35983.547643640001789023')

# %% [markdown]
# 就是这样！使用 Web3.py 从智能合约读取数据就是这么简单。

# %% [markdown]
# # 发送以太坊交易
#
# 欢迎来到由 6 部分组成的教程系列的第三部分。在本视频中，我将向大家详细介绍如何使用 Web3.py 在以太坊区块链上创建交易。本课程适合从初学者到高级用户的各类人群，我将从基础概念开始，逐步深入讲解。在学习的过程中，你不仅能够掌握 Web3.py 的使用方法，还能深入理解以太坊区块链上交易运作的基础知识。
#
# 每当你在以太坊区块链上创建一笔交易时，实际上就是在向区块链写入数据并更新其状态。创建交易的方式有很多种，例如将以太币从一个账户发送到另一个账户、调用能够写入数据的智能合约函数，以及将智能合约部署到区块链上。通过使用 Web3.py 库来执行这些操作，并仔细观察每个步骤的工作原理，我们能够更加深入地理解这些概念。
#
# 为了将交易广播到网络，有多种方法可供选择。在本教程中，为了保护私钥这一极其敏感的数据，我将使用个人开发的区块链进行演示。我强烈推荐大家使用 Foundry + Anvil 组合作为你的以太坊开发个人区块链。Foundry 是 Rust 生态下的一个强大的智能合约开发工具链，而 Anvil 则是它提供的本地 EVM 模拟器／节点。该工具在 Windows、Mac 和 Linux 系统上均可使用，并且提供了桌面应用程序和命令行工具两种形式，方便你根据自己的需求进行选择。
#
# 以下是安装和启动 Anvil 的命令：
#
# ```bash
# curl -L https://foundry.paradigm.xyz | bash
# anvil
# ```

# %% [markdown]
# 您可以在此处[https://github.com/foundry-rs/foundry]找到适合您操作系统的最新版本。下载存档包后，解压安装程序并执行设置步骤。安装完成后，每次打开它时都应该看到此屏幕：
# ```
#
#
#                              _   _
#                             (_) | |
#       __ _   _ __   __   __  _  | |
#      / _` | | '_ \  \ \ / / | | | |
#     | (_| | | | | |  \ V /  | | | |
#      \__,_| |_| |_|   \_/   |_| |_|
#
#     1.4.3-stable (fa9f934bda 2025-10-22T05:33:20.255411000Z)
#     https://github.com/foundry-rs/foundry
#
# Available Accounts
# ==================
#
# (0) 0xf39Fd6e51aad88F6F4ce6aB8827279cffFb92266 (10000.000000000000000000 ETH)
# ......
#
# Private Keys
# ==================
#
# (0) 0xac0974bec39a17e36ba4a6b4d238ff944bacb478cbed5efcae784d7bf4f2ff80
# ......
#
# Wallet
# ==================
# ......
#
# 0
#
# Listening on 127.0.0.1:8545
# ```

# %% [markdown]
# 太棒了！🎉现在您已经拥有一个正在运行的个人区块链网络！

# %% [markdown]
# 现在让我们代码连接到 anvil，而不是 Infura 节点：

# %%
from web3 import Web3

anvil_url = "http://127.0.0.1:8545"
web3 = Web3(Web3.HTTPProvider(anvil_url))
web3.is_connected()
# Out:
# True

# %% [markdown]
# 现在从 anvil 复制前两个帐户并将它们分配给如下变量：

# %%
account_1 = web3.eth.accounts[0]
account_2 = web3.eth.accounts[1]
print("account_1 余额：", web3.eth.get_balance(account_1))
print("account_2 余额：",web3.eth.get_balance(account_2))
# Out:
# account_1 余额： 10000000000000000000000
# account_2 余额： 10000000000000000000000

# %% [markdown]
# 接下来，从列表中获取第一个帐户的私钥。前往 anvil 的终端显示， 找到 Private Keys。复制私钥后，将其赋值给一个变量，如下所示：

# %%
private_key = '0xac0974...'  # 替换为 account_1 的私钥

# %% [markdown]
# 现在让我们构建一个以太坊交易，将以太币（ETH，以太坊的加密货币）从 account_1 发送到 account_2。我们可以像这样构建一个交易字典，该字典包含将广播到区块链的所有必要信息：

# %%
nonce = web3.eth.get_transaction_count(account_1)

tx = {
    'nonce': nonce,
    'to': account_2,
    'value': web3.to_wei(1, 'ether'),
    'gas': 2000000,
    'gasPrice': web3.to_wei('50', 'gwei'),
}

signed_tx = web3.eth.account.sign_transaction(tx, private_key)
tx_hash = web3.eth.send_raw_transaction(signed_tx.raw_transaction)
web3.to_hex(tx_hash)
# Out:
# '0x007a4876a06e0e2b22f83f05e5a5b92d0000d99f5b0fed5e64197620c81adc53'

# %% [markdown]
# ### 代码解释：
#
# 1. **获取 Nonce**
#    ```python
#    nonce = web3.eth.get_transaction_count(account_1)
#    ```
#    - **Nonce** 是账户发出的交易计数（从 0 开始）。
#    - 它是一个必填字段，用于防止**双重支付**（double-spending）和**交易重放攻击**（replay attacks）。
#    - 每次交易被确认后，nonce 会递增。
#
# 2. **构建交易对象**
#    ```python
#    tx = {
#        'nonce': nonce,
#        'to': account_2,
#        'value': web3.to_wei(1, 'ether'),
#        'gas': 2000000,
#        'gasPrice': web3.to_wei('50', 'gwei'),
#    }
#    ```
#    - **`nonce`**：当前交易的 nonce（必须与账户的当前交易计数匹配）。
#    - **`to`**：接收 ETH 的目标地址（`account_2`）。
#    - **`value`**：要发送的 ETH 金额，使用 `web3.to_wei()` 转换单位（这里发送 1 ETH）。
#    - **`gas`**： gas 限制（即最多消耗的 gas 数量），这里设为 2,000,000（足够完成普通 ETH 转账）。
#    - **`gasPrice`**：每单位 gas 的价格（50 Gwei），影响交易被打包的速度（价格越高，矿工越优先打包）。
#
# ### 补充说明：
# - **`gas` 和 `gasPrice`**
#   - `gas` 是交易执行的计算资源上限，如果交易消耗的 gas 超过这个值，交易会失败并回滚。
#   - `gasPrice` 是你愿意为每单位 gas 支付的费用（1 Gwei = 10⁹ Wei，1 ETH = 10¹⁸ Wei）。
#   - 你可以用 `web3.eth.gas_price` 获取当前推荐的 gas 价格（动态变化）。
#
# - **签名交易**
#   上述代码只是构建了交易，尚未签名。要广播交易，还需要用私钥对交易进行签名：
#   ```python
#     signed_tx = web3.eth.account.sign_transaction(tx, private_key)
#     tx_hash = web3.eth.send_raw_transaction(signed_tx.raw_transaction)
#   ```
#   （注：实际使用时请妥善保管私钥，不要硬编码在代码中！）
#
# - **动态 Gas 价格（可选）**
#   如果你想优化手续费，可以动态获取当前 gas 价格：
#   ```python
#   gas_price = web3.eth.gas_price  # 自动获取网络推荐的 gas 价格
#   tx['gasPrice'] = gas_price
#   ```
#
# ### 关键点总结：
# 1. **Nonce** 确保交易顺序正确且防止重放。
# 2. **`value`** 必须用 `web3.to_wei()` 转换单位（ETH → Wei）。
# 3. **Gas 相关参数** 影响交易执行成本和速度。
# 4. 实际使用时，务必通过安全方式管理私钥（如环境变量或密钥管理服务）。

# %% [markdown]
# 最后我们观察一下余额的变化

# %%
print("account_1 余额：", web3.eth.get_balance(account_1))
print("account_2 余额：",web3.eth.get_balance(account_2))
# Out:
# account_1 余额： 9998998950000000000000
# account_2 余额： 10001000000000000000000

# %% [markdown]
# 耶！你已经成功使用 Python 将 Ether 从一个账户发送到另一个账户了！

# %% [markdown]
# # 使用 Web3.py 调用智能合约函数
#
# ## 准备工作：部署智能合约
#
# 在调用智能合约函数之前，我们需要先将智能合约部署到区块链网络。这里我们使用 Remix IDE 进行快速部署（无需本地安装开发环境）。
#
# ### 1. 使用 Remix 部署智能合约
#
# 1. 访问 [Remix IDE](https://remix.ethereum.org/)
# 2. 创建一个新文件 `Greeter.sol`，粘贴以下简单合约代码：
#
# ``` solidity
# // SPDX-License-Identifier: GPL-3.0
# pragma solidity >=0.8.2 <0.9.0;
#
# contract Greeter {
#     string public greeting;
#
#     constructor() {
#         greeting = "Hello";
#     }
#
#     function set_greeting(string memory _greeting) public {
#         greeting = _greeting;
#     }
#
#     function greet() public view returns (string memory) {
#         return greeting;
#     }
# }
# ```
#
# 3. 编译合约：
#    - 点击左侧"Solidity编译器"标签
#    - 确保编译器版本与合约声明匹配（^0.8.0）
#    - 点击"Compile Greeter.sol"
#
# 4. 部署合约：
#    - 切换到"部署和运行交易"标签
#    - 在"Environment"下拉菜单中选择"Injected Provider - DEV "Foundry Provider"（测试用）
#    - 点击"Deploy"按钮
#    - 部署成功后，你会在"Deployed Contracts"部分看到你的合约
#
#
# ![](images/contract_deploy.png)
#
# ### 2. 获取合约ABI和地址
#
# 部署后，你需要记录：
# - **合约地址**：在Remix的"Deployed Contracts"部分显示
# - **合约ABI**：在编译后，点击"ABI"按钮复制JSON格式的ABI

# %% [markdown]
# 编译后的 ABI 如下所示（您可以复制它以方便使用）：

# %%
abi = [
			{
				"inputs": [],
				"stateMutability": "nonpayable",
				"type": "constructor"
			},
			{
				"inputs": [],
				"name": "greet",
				"outputs": [
					{
						"internalType": "string",
						"name": "",
						"type": "string"
					}
				],
				"stateMutability": "view",
				"type": "function"
			},
			{
				"inputs": [],
				"name": "greeting",
				"outputs": [
					{
						"internalType": "string",
						"name": "",
						"type": "string"
					}
				],
				"stateMutability": "view",
				"type": "function"
			},
			{
				"inputs": [
					{
						"internalType": "string",
						"name": "_greeting",
						"type": "string"
					}
				],
				"name": "set_greeting",
				"outputs": [],
				"stateMutability": "nonpayable",
				"type": "function"
			}
		]

# %% [markdown]
# 请注意，设置了一个“默认”帐户，我们将在上面的示例中使用它与区块链进行交互。

# %%
import json
from web3 import Web3

# Set up web3 connection with anvil
anvil_url = "http://127.0.0.1:8545"
web3 = Web3(Web3.HTTPProvider(anvil_url))

web3.eth.default_account = web3.eth.accounts[0]

# %% [markdown]
# 现在像这样存储智能合约地址（**注意它必须是校验和格式to_checksum_address**）：

# %%
contract_address = "0xe7f1725E7734CE288F8367e1Bb143E90bb3F0512"
contract_address = web3.to_checksum_address(contract_address)
contract_address
# Out:
# '0xe7f1725E7734CE288F8367e1Bb143E90bb3F0512'

# %% [markdown]
# 接下来，我们将像这样初始化合约：

# %%
contract = web3.eth.contract(address=contract_address, abi=abi)

# %% [markdown]
# 接下来，我们可以像这样读取默认问候语：

# %%
contract.functions.greet().call()
# Out:
# 'Hello'

# %% [markdown]
# 最后，我们可以通过调用 set() 函数来设置新的问候语，如下所示：

# %%
# Set a new greeting
tx_hash = contract.functions.set_greeting('nihao').transact()
# Wait for transaction to be mined
web3.eth.wait_for_transaction_receipt(tx_hash)
# Display the new greeting value
contract.functions.greet().call()
# Out:
# 'nihao'

# %% [markdown]
# # 使用 Web3.py 部署智能合约
#
# 智能合约是部署在以太坊网络上的自执行程序。部署前需完成以下环境配置：
#
# 环境准备
# 安装 Solidity 编译器支持库：
#
# ```bash
# pip install py-solc-x
# ```
#
# 安装指定版本的 Solidity 编译器（示例使用 v0.8.30）：

# %%
from solcx import install_solc, set_solc_version
install_solc(version='0.8.30')
set_solc_version('0.8.30')

# %% [markdown]
# > 强调：set_solc_version 函数确保您使用的是正确的编译器版本。

# %% [markdown]
# 您现在应该准备好编译和部署contract。
#
# 以下示例贯穿以下步骤：
#
# 1. 将 Solidity 合约编译为字节码和 ABI
# 2. 初始化合约实例
# 3. 使用 Contract 实例部署合约并发起交易
# 4. 使用 Contract 实例与合约函数进行交互

# %%
from web3 import Web3
from solcx import compile_source

# Solidity source code
compiled_sol = compile_source(
'''

// SPDX-License-Identifier: GPL-3.0
pragma solidity >=0.8.2 <0.9.0;

contract Greeter {
    string public greeting;

    constructor() {
        greeting = "Hello";
    }

    function set_greeting(string memory _greeting) public {
        greeting = _greeting;
    }

    function greet() public view returns (string memory) {
        return greeting;
    }
}
''',
    output_values=['abi', 'bin']
)

# retrieve the contract interface
contract_id, contract_interface = compiled_sol.popitem()

# %%
# get bytecode / bin
bytecode = contract_interface['bin']
# get abi
abi = contract_interface['abi']

# %%
# web3.py instance
w3 = Web3(Web3.EthereumTesterProvider())
# set pre-funded account as sender
w3.eth.default_account = w3.eth.accounts[0]

# %%
Greeter = w3.eth.contract(abi=abi, bytecode=bytecode)

# %%
# Submit the transaction that deploys the contract
tx_hash = Greeter.constructor().transact()

# Wait for the transaction to be mined, and get the transaction receipt
tx_receipt = w3.eth.wait_for_transaction_receipt(tx_hash)

# %%
greeter = w3.eth.contract(
    address=tx_receipt.contractAddress,
    abi=abi
)

# %%
greeter.functions.greet().call()
# Out:
# 'Hello'

# %%
tx_hash = greeter.functions.set_greeting('Nihao').transact()
tx_receipt = w3.eth.wait_for_transaction_receipt(tx_hash)
greeter.functions.greet().call()
# Out:
# 'Nihao'

# %% [markdown]
# # 使用 Web3.py 检查区块
#
# 如何使用 Web3.py 检查以太坊区块链的区块。分析以太坊区块链的历史记录时，检查区块通常很有用。Web3.py 有很多功能可以帮助我们做到这一点。例如，我们可以在 Etherscan 上构建类似这样的区块历史记录功能：
#
# ![](images/block_history.png)
#
# 让我们开始使用 Web3.py 提供的一些功能。这个设置比之前的课程简单得多。我们将重新连接到主网来检查那里的区块：

# %%
from web3 import Web3

# Fill in your infura API key here
infura_url = f"https://mainnet.infura.io/v3/{YOUR_INFURA_API_KEY}"
web3 = Web3(Web3.HTTPProvider(infura_url))
web3.is_connected()
# Out:
# True

# %% [markdown]
# 首先，我们可以像这样获取最新的区块号：

# %%
web3.eth.block_number
# Out:
# 23644813

# %% [markdown]
# 我们还可以像这样获取最新区块的所有数据：

# %%
web3.eth.get_block('latest')
# Out:
# AttributeDict({'baseFeePerGas': 98176494,
#  'blobGasUsed': 393216,
#  'difficulty': 0,
#  'excessBlobGas': 393216,
#  'extraData': HexBytes('0xe29ca82051756173617220287175617361722e77696e2920e29ca8'),
#  'gasLimit': 45043772,
#  'gasUsed': 39905046,
#  'hash': HexBytes('0x0789473cf3dfd0b0bb9a2e62b00a8615ce4c122677bd0d1f3fec99bd93460a41'),
#  'logsBloom': HexBytes('...'),
#  'miner': '0x396343362be2A4dA1cE0C1C210945346fb82Aa49',
#  'mixHash': HexBytes('0xed43e9a0a48a5fa125681adb03a6c4e3590e58b11986d1c3ed691974a1c6dee9'),
#  'nonce': HexBytes('0x0000000000000000'),
#  'number': 23644813,
#  'parentBeaconBlockRoot': HexBytes('0x1c365e94c3fd9e7abdd86bdf69b83507dccaa1bebf88ffae504239002798e91f'),
#  'parentHash': HexBytes('0xbab3a1dd833a5d9ea01cb52dd7a88e03e3c9f626ac7c4c93f3be242f3b673957'),
#  'receiptsRoot': HexBytes('0xca0ae41cd8279c83023294d125cf8f672ac16e82d7aaa241676518ee08d4ef84'),
#  'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'),
#  'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#  'size': 101261,
#  'stateRoot': HexBytes('0x663860cf65ecdb107449940ce3b0353fd58eeef37df8f18b86579323b8ff246a'),
#  'timestamp': 1761278495,
#  'transactions': [HexBytes('0x64b4a2bb72487e2ed563bbbccc844caf4a12e2ce3dfd9d98d49d74ab7d50103c'),
#   HexBytes('0xfbe83285263d995ab25c8b089ef989cf972d409388731060b260eab0a276dbac'),
#   HexBytes('0x5105670c38a4f27e061d1380eb558c6f1a16c20d9a9baf75511f74c01f22f205'),
#   HexBytes('0x8161caa1f92afe0d59856507f4db8be66f33a7a7e777b0d3729fab0228b27c86'),
#   HexBytes('0xf91fc67d10618c9b7675c2ab90822d27f3f5007cee2eed1d77568dfb0e5bcbf0'),
#   HexBytes('0xea0220b644ab67a4e817d8087ebf24a848cb85bb1aec5ab34d2668c2156bf582'),
#   HexBytes('0xe1bcb76eb85ba2f256541494f7c8767037c4a15a9dacb001241edc834aec7ced'),
#   HexBytes('0xc7d93942d64df8b3b7d591020b1e67faf958e38133958165982cc97c8a665fef'),
#   HexBytes('0xd0f2e98ecc58601b82cb58680c4988ed5cf219ae0fe1992aa626177aec0f5f93'),
#   HexBytes('0x311a40f351093c56c26b40cc127444e078cfc1713b523008fbda5f3e45495975'),
#   HexBytes('0x58bd4a8fb2120361080539ee5d1f0537ebf154273beb9e4e4ee81c572f97e6d9'),
#   HexBytes('0x4abeca00c2ab6ac07982096a2a781b16e3e1b627d5955ea5891efe4935958b56'),
#   HexBytes('0xc396274be1eda94a5a359bd7567f8e2630d6edaf46dfb83b6742c309ed7250f4'),
#   HexBytes('0x2fad42e4d0c712765e0c8b0c273d611370e9626076d3c9e84cb12fd89b112621'),
#   HexBytes('0x1c616432bec02aa164411f23f714951c2d4ee15e196a4d2c63fc62a559354877'),
#   HexBytes('0x0040d368fd0ebdcd500b84244ed3907bea93a9192d83c4f9c97700d467c6ab71'),
#   HexBytes('0x3413415d639f850fd21b98e529f9c64ce91edbf51edd9dca79f8aa617f00de84'),
#   HexBytes('0xa29863dabeb776b7097998c6339cfe07a6021771db45224a672acea13dd97c2a'),
#   HexBytes('0x4ffc1a21d2328f0332f9df4560f3dc2d8d977086d4e4773695b3700f02517713'),
#   HexBytes('0xa90518096b58a8f01a33706e6e36d81d0ff2d21454717659be276741eb3a5b77'),
#   HexBytes('0x2cd120f54eb35f455c7c04f4df728c60e1137b2d19f8875004e05cf7dbd71602'),
#   HexBytes('0xf16e40db3cc7c7b7204b97472e31cb6f867f547d155a53deadf0ebe52e8594ad'),
#   HexBytes('0xc797e680159e268146c83dc6e167d2d221d78b14ce27372090010bc3108c2b67'),
#   HexBytes('0xbc24c4b6e3a98142e19512d552ddf16b402e1e2bda02811a1e3e5a7c4ee7a42a'),
#   HexBytes('0x9994610ec174c1acca7eff022d346b5a373f88193aec5f17ca2dab2849498bec'),
#   HexBytes('0x8d713f9daea953273d8623c32f113cea5924d1b3d447f0fcc9c120fa226a18ed'),
#   HexBytes('0x371a383c20b75c9ad21bbb029c8a1d56b2f233d0b43a79e1e5695bc27a931c49'),
#   HexBytes('0x3021a8189a3954c7db070b969c90666cd82b17cd157bc55287d1f9e91cb057c9'),
#   HexBytes('0x03d0161471c9c77ab84969be730fd1d3940d0154284b2307aee1b439c3456321'),
#   HexBytes('0xf594f4cc83ad4082decc7ea59103047f64aa119d30c58237c1efe7a034fffca6'),
#   HexBytes('0xf05529a301c686509c5ad4e78f9ce73eaf6dd380382a8745085043d4db79ef69'),
#   HexBytes('0x799173b2ef7912fd88335d0025889289927c4470647aa771f8f5aaf24fd874c5'),
#   HexBytes('0x44491397475ac6ce710e76c1c9917f4d3514ded8bfc8de33111ee00695d8ae34'),
#   HexBytes('0x28c6cacb1468fc06d53b183ed6d7facb6868c861703ad0ca2e2a3c8c4b7bef95'),
#   HexBytes('0x21103f370923d890f6ab96c8892634a9567822287256153844fe836d72ba757d'),
#   HexBytes('0x13873df50998dec4c50a4764e78e99e9e8435738e99e866d8def5cb7dd752bd7'),
#   HexBytes('0x113b09afd9af3ed904ed18814234c10ed27965489eee78cefde0a1abc5259bc9'),
#   HexBytes('0x0c7ceb2cd75811cc2ce5ddfe85ad16f19d595de2a5c2888c056498b7c2c313e9'),
#   HexBytes('0xf0c6bdf1c41c69a4ff2cca267bad7ee6e25cbd529228761376855570586b594e'),
#   HexBytes('0x0aecd7837a3030235810f3162f9616bb0d00fe1640d0cd00ba191296b12da8fa'),
#   HexBytes('0x27a9518284439d9c10cf072a7bfe0ea1268652831abc07e6d68043bc189e7ec6'),
#   HexBytes('0x8b80e84ff91e6e6747cf185be3cadac042c60ce1237e2c3291fd9515c935ce02'),
#   HexBytes('0x839431d9b5a8216eb7c46bf9aa69c36d2eb1ebfa16abbb6aee2b872aecefd1f2'),
#   HexBytes('0x6403cd92045055a4afd52633466a22b99ad453d6c0a7dcc6412a3798e4d2731c'),
#   HexBytes('0x27762b33702658f46a83259395f156e9a0839151b091d9f4be10e8a20992d8bd'),
#   HexBytes('0x87ce03f9b2d1db6ce3b9281b1196885f8556bd46de4765a2842e281ab21aa2a7'),
#   HexBytes('0xf4ac0161ee923f3d2c2c7ddf5597fa4ce6c42addbd8075e8b3b643b107abb5e8'),
#   HexBytes('0xcfea06b3922157076cc48e70b790f8648f8441d1626ac633ba13a7d15efead7c'),
#   HexBytes('0xa72a364c8550837da79b9cd3f7081f780a037f1c860007cb8af72d8bd1fa0087'),
#   HexBytes('0x83b4320ab8b9a9024e69c4270432535bf72949bff14d0e794805448e76ebeec3'),
#   HexBytes('0x2dd2a6dbb75b05c1eaf51dd20a7caeb4dcb25050231dafe0b72ae32888161990'),
#   HexBytes('0x46192cf18217a5e5611142b2b63b58344c70722874370bf1dac302aeb45e1651'),
#   HexBytes('0x180788a58a2c3d04d9b5751d3bdeb7b66a42e73c14d7376349a21f724b1fb86b'),
#   HexBytes('0x6f559824c35ae3a8d64f5cab9790110bb9d511c4a1d3e14f2dd1593927c3ac11'),
#   HexBytes('0xfb43070797841cb8eb086ef9a3b7a8682a3e04852a75bcadf1e01401f65d667f'),
#   HexBytes('0xf1043ff437cf4eb850d332146d144ec034a355131b77969ed9ec588d5aa1e307'),
#   HexBytes('0x36667ef8659e158df8e1eef9c49e6880a2e138e3b5b22acc21d7bc4548e3d3ad'),
#   HexBytes('0x263ccb49a62ac4afa61700d57507db64aad3a8cbebe52bbb1b29bdf3d02acd71'),
#   HexBytes('0xc5fe43e2ba17189ef47134a28586424e8e83811ec58c9c8c336902aab90eb85a'),
#   HexBytes('0xabc33ec8a47a9509b821182477d7498636db52615c209601918a9f0f5f4bbad2'),
#   HexBytes('0xec852984f6d05431cbaef2e373ae2d1824ce6a343cf56ece97c93c3bbdd96f84'),
#   HexBytes('0x034566aeb2bac9b3c682b9c83ff405f670cedc6c76f732cb36a7395d8d31813c'),
#   HexBytes('0xfa2e30974447478f6d652af13bb4de2b331863137f28d68364e24a40f3ee2a31'),
#   HexBytes('0xa915ca35181e8fec9cc03feacc7218aaa2dd18a99f74feb5d53ace4199306aea'),
#   HexBytes('0xd827357447d1891626bef2a9fbac5741b9e6c05b5a1a6b30fa503fbb59467dc6'),
#   HexBytes('0xefe293d4cb94fcef12f22c4d6ba8fb717f2cc89135b7c146e4d39122a11c5b1b'),
#   HexBytes('0x37bfd7fcac9574732289f420c9377e86eed7bd6f9c3df9c18cc4458db1c9a62c'),
#   HexBytes('0xd950951bba53ede4fab8aa50d92fe81027b8c0470ff43882aaff8a06b1ce4710'),
#   HexBytes('0xa5af2e18e411382831fa0fcedbe171fea35f4e1bcd5859d3b5f6fb6b887d6046'),
#   HexBytes('0x6869939d84247ab7f80762b846b058791aec27c7aea67d73cd5a9f0bce2fbe0b'),
#   HexBytes('0x4d4b8c356e2efe13a640799615e0cf0023d6bc705922b0090e349e7728ff671d'),
#   HexBytes('0xc7e1c4083ddd72d4ca87a429f5b1083a45a475a7cfd8f50561538891c132ee97'),
#   HexBytes('0x43ff905f32c07016dd82accb87aaf36a18b7a05182747358eefb5aded6328b79'),
#   HexBytes('0x269aac6121c8bbbfbecc34db65a15b736471a06de7c0130bfabcf42fb84be59f'),
#   HexBytes('0x5d2fddbecf95df0481abc2eea9c34d61f8a21886e2f6eced7eca37a9034d0dbb'),
#   HexBytes('0xc03787472838c9471e705bcf5767b4bfa801a984a5d066e81805f3e45b9badb2'),
#   HexBytes('0x1f3ae9c928570e04d70c89f0ec54931305853ec94775ff0b318350e20c434794'),
#   HexBytes('0x2a717562ea2b2035d217c05b34c275ac3ca679515d6301df5df7deb3900271a7'),
#   HexBytes('0xfc98f944327c284584255e9354c2e1dd4afad04a748cdebf9c912f961e9b4e64'),
#   HexBytes('0x137296fb06c98c287a949c9d33a5c7fb89d11b8f39a377194675809317469e02'),
#   HexBytes('0x8fcaf286b73df8ceca2500e81f1a738599f58de8d877a5bd212299fd0c523c95'),
#   HexBytes('0x856c5d8fe260cc05b754df4c1ac0b7cff4a706ea4be8aae7b92d5a17d82dd7cb'),
#   HexBytes('0x53b09336efba412fe5f279caa3e9e9a542a1a589b4ff435d075eb9abc6ed9603'),
#   HexBytes('0x27db9dbcdf077b36fab72f7a932a6345c6d5bf20b9fb3c07af2b793dd0b345cd'),
#   HexBytes('0x134c7888ad2d11b364af3f51d5b0807980ba04a666f0296dea28b275d9d5bae9'),
#   HexBytes('0xedd8faab0d9777423ce3a777a54e66b14999e58bb63a09da50e016ad3353628b'),
#   HexBytes('0x88dc5c5b82e76300dfffdf828c76efc4d010b1f1f06599ab9a61545c61508064'),
#   HexBytes('0x850ca352611398e120ea458b545a6404156786e57d7648defd44dbe14b42b6fe'),
#   HexBytes('0xefbc3b66b0a9d918c4662b91f6a3860d0f41d7e583834badc5fe0581d5bedf52'),
#   HexBytes('0xa05b321629d349197f404805bf281cb83969762d866ed2b4a8e3eb5e35b616b4'),
#   HexBytes('0x27ce8f0842f288bfb9b159e80b0fd04df0c4530cd07b41b68d915a6640f607c4'),
#   HexBytes('0x3f2eb51bdbf538b8266508bbcd0241f88ff1e4c284fc7b6f27ea9392a9c641d5'),
#   HexBytes('0x1497c7c5ccfa9c817e36976fd31500dc31f053e4b210e936f09544298a460481'),
#   HexBytes('0x98fbb00e3684882bbeaf3d19095444acbefccb48b31b0643409b73e22e53d70d'),
#   HexBytes('0x54fbac6b6593a5b44e16c916bd45a4befa5d27b8c5df10f0cadc4be56ad6eae3'),
#   HexBytes('0xee0684cd55eaeb9b4ad53544320e67ee0cda43f8e6ebd78ad98e3e6c759adff5'),
#   HexBytes('0x0ab6702e6adfaf81b641421e56938276b9840d81285c5b31154593d75deb55ed'),
#   HexBytes('0xedf5b6e0d6e57e4c15cfdd42aeef638831fbd3d8201527b0b5f199aedae9fc29'),
#   HexBytes('0xf6870266d8ed9c6c2c785bef9a4cb1a7ccbe582b3c7cac6916d990b3a766f7ee'),
#   HexBytes('0xdff654199ab18c48fc81f79137dc3fdaded16ddd3e47e2bbcc2442efa9dbff76'),
#   HexBytes('0xd15dc5c046ef5089733c7dfdd117bdead23ac511c7d943140243442faef8d4a2'),
#   HexBytes('0xb6d5e6cdf52cef2eadda66e6e2529a8d6d8b846d408dad178aaf592afe625c5b'),
#   HexBytes('0xa3a9775f08d65e11c6a152c1b4689c32f1773fb4c419cb481a00792bab945047'),
#   HexBytes('0x3c9272877f770d81853b279dc917853fe898ba7fb5306cd9d60ca66a253832b8'),
#   HexBytes('0x37dac70faf4f9370d32381131c1ac8da9975553ea3c75dca1630fe9b3bd5de25'),
#   HexBytes('0x6c36b28e58fa6ea902ddcd2f4b9b701c4043063d553cb7db0ba08ba8088282db'),
#   HexBytes('0x8b2136eb67bb090e118106e8d9f3d5240c974f7d15877cc52f8ccd544ceb2daa'),
#   HexBytes('0xbd8acd38931ea7ce5b4d5a0dce12d730f70620b5d442aa93d8a6428e5db44dfd'),
#   HexBytes('0xeee0387788a2e7371751ac71d2d5d95320acc62eb284746b8545d67a28d21c15'),
#   HexBytes('0xe8d3e3c56e7af715c0ffa1819d77bff478f3e5b182b66bc60bd348d223f961d2'),
#   HexBytes('0x80c85da5225a7ad1ebee4efdbf2ca898ff89be843d8b09ce458a0fd3b93a182d'),
#   HexBytes('0x40aacd6e4d64478d8e1c207a0628046b37c9c4e7f0828ea81f238944c2ebf209'),
#   HexBytes('0x4dcd8af23b18b1ebc97652ef14daa867d0be55be6dba62170a3c6b195972c6d2'),
#   HexBytes('0x2c83bb6df0ddb1b81a0a0c2b2966eba9f9fbe618ac47c5d926cce70befb89463'),
#   HexBytes('0xe2197fb6f6b0e30ac4d30706d216efd706b485a0094d470bc3e3804f945a8927'),
#   HexBytes('0xb228e6f691c73b1d6de3fa47c16e28c05002468e2f683df53652da18627ab008'),
#   HexBytes('0x7c4ec911c7c836aaa1694e23a6e535e25abf629c2c05dd22698be7083197af71'),
#   HexBytes('0x533d562c466de2be402667d6acc03e183b746822d3195165b98131f5f0cd2f31'),
#   HexBytes('0x060bed59cdd1521105b30046618ba07474ece442c38305eee5d6cb2eb904e1bd'),
#   HexBytes('0x42b83e30fbc2d5bb771f2f63411fb698ad0f6f0d316013f3dde8d96b34da18a9'),
#   HexBytes('0x5532ceaa24614c26bb3839687b038fe35057dfdd3910dbe80faf794486e27d59'),
#   HexBytes('0x4c34ccb7653a39735d81c9a7c88308d9b92a900812efabb52a7ae903356bc42a'),
#   HexBytes('0x32277414b5c0eaaec6f5e6e557202575b4ad3420f750fbfa8ef9c14af80070c1'),
#   HexBytes('0x0ab11dab7225f42927c8ff5919927d8e49911975d92f244cdb043e75e4bca89f'),
#   HexBytes('0x9eadcc1808f4dd4fe9be540572994e59d909071aeeb79c065d3052f543c36c99'),
#   HexBytes('0xf43a9d4599f2c512fe1a8c1ee73830807c9b08765b0d578a41c1e04a74c05ac0'),
#   HexBytes('0xc5bc47e5bc51841f673065c5b8e86e0ecf96355ac4c3b745b4fd4894a3da0198'),
#   HexBytes('0x8afe8ed18bb3b94d55bc6f00ef41a9d89d7e29a7e07183c033a7082e92790ee7'),
#   HexBytes('0x6088b5972c70885d9b7a0866a0d6bcdcab988ecb9110a213c1b13a8ca786498b'),
#   HexBytes('0x93e32366d259d58b54c7542390f45074370e002384b99f54b77eb77929f2e0b4'),
#   HexBytes('0xfd18aa701649659330eb50061ad405ef0e4ba988c6fc78ee9ce960df2d54f534'),
#   HexBytes('0x5f9f23d1ccfadb3304419f697cb4801c0b2c14092f81d688c581350a4084bec5'),
#   HexBytes('0x42a9e24a94af028fe0402ce4c4441e16b3d37c1833d5f558b7b7304763a20ddd'),
#   HexBytes('0x7abd410bdb056e86622d9930a3eed09b7ff40569d8441a76464d42a665daaf4f'),
#   HexBytes('0xa09bd99555db602e7381e3b6be9ced44bf03f1d6dc70749a74eebd9a1fa6dd25'),
#   HexBytes('0x75d6a6db3ef6e17fa664943e9a93d362b4f71469759bc47ae58c791ce9e6ef04'),
#   HexBytes('0xd3a265187dbb9c7e66ff348a78ed0695c258882b3ff8fb624c0fd31e9f1891ed'),
#   HexBytes('0x517b8fe2c890b6bf0b743ee2061b5337eaf06c1492d40cd7fc6ce3bec5b5bf52'),
#   HexBytes('0x62b12bca4eddbbce28c953165607e42a8aae29158f507475f9096f431a16a34b'),
#   HexBytes('0x2cbf1b2d3a4c2ad8cba8aba341668c87fee82f88b4bf0857a9bb410dee547252'),
#   HexBytes('0xd3bfba9b1c2594a8af317f71062b2a18cde6f630ebcbf6a073cc7145d3579c3b'),
#   HexBytes('0x86393e76eb2f68a99d725c5e8ac5ee2dbfdb33ae3bacadf7f3e0bfa0f0db8c43'),
#   HexBytes('0x1ca26f72addd70fd3e18605ae4bfa0902d8d7380b90bea69dbd7dddbeb17b9ba'),
#   HexBytes('0x15c0d19ac35f8d138ec68b2295a7e9e12e8f89ec026f46fe204f1043ade5a08a'),
#   HexBytes('0x9917ab862d4a53f734b59643e4bb6a32a4c204044561284156bff8ea1c1f90c3'),
#   HexBytes('0x8e8f4134d4c869b86cf482d33f6cd7c87c623f7df0ecef467d4e306932d3e760'),
#   HexBytes('0x0bf7add500195276369a47f1837a0d587a7602d64a7e17a1e01628b8ae4336f0'),
#   HexBytes('0xf4768aa777045278798987610f6e574f200a1b7a4727045aebda002540f2060e'),
#   HexBytes('0x91bc827192d733a4bb480ab0e70ed1f6a74ef425836aac40c92f356b7d95188f'),
#   HexBytes('0xc5956e9d3959b3d43633c52f58521e4d504406e8e006ec785b14c9935b5e5910'),
#   HexBytes('0x75cb335a51063b92db1780ef1e3ced77bd4a4e86dfcf3e0769cd22ac1f3b9122'),
#   HexBytes('0x2d4c7bf0c865897ca3e651b10317b51438b03119e832eaa4a684354744049941'),
#   HexBytes('0x200558305669fd281f2feb667dc412b9ed958de22d054cbc239092acf512af52'),
#   HexBytes('0x05bb66e9229fcd4d020071d432af539d76ccdd144078892989971c1d42ac993a'),
#   HexBytes('0xa556738b7f70667fab4f07f695766a21cbd3273b891a8da48592d6be953cea75'),
#   HexBytes('0x19a388c923b02efb61805191fe082e6d1d5b8cb60b03611f2d0d0bb2de021abf'),
#   HexBytes('0xa3ef819b6fc801984fa215dee7c77b7f82c47e387ff51244c99afe0bf5941c14'),
#   HexBytes('0x6cbbf0234942336df085e86b2425597058cb87117cd99253ff34b764933d03a1'),
#   HexBytes('0xc868d0e9dd52389f76758368a2e14063ba84dbba4a4f27236a7a1b1cf63f8555'),
#   HexBytes('0x5435051ae8acfef2cfe5afcfa77f97d7b6d7c9e91f3c5783917d2fc12cd189f3'),
#   HexBytes('0x10f68f7272937db092b0ac61ae18977a72108152c239b50438862530436f66c2'),
#   HexBytes('0x92d874509d25eacdb903fb0e22c0078c8c62fd49a39c3e2f81e1bb9db40d5d56'),
#   HexBytes('0x255da53ec7fd48194663ccc3687b9c65e44e017721f09ae40d10d291f02e91bf'),
#   HexBytes('0x865290294f5451a1ef9b43f4f5be85b80c8f0f42e93e64b375497dce0b483c4e'),
#   HexBytes('0xc1a50b6e6988722aa5a87c3a43d1238cb1266c9a35135d23680bb7e959e4d5fd'),
#   HexBytes('0x03e40fdcef02b873de9a82f529fa67939c35af77b69e9a0e41001b346b7a5d61'),
#   HexBytes('0xde27809a4f1e72c22f4e49f531d103188b2c4a913c44e4a72d78404b997e2521'),
#   HexBytes('0xe45ea40b7a2a683568f3a1ec267f89747182940b5e5c43a470713f0d0437f3a7'),
#   HexBytes('0x780ffc84e3e7304d797090ccd82064baa5168908f47e81633b8a521123c85716'),
#   HexBytes('0x39fbd11ee08eb6bc08dfbb361eec25b95a5613b82298e3db600e71f06f5b218e'),
#   HexBytes('0x82a26310f5e816e144e2b7388653630d96b70094d9c68b7ac3c71662cc178dd9'),
#   HexBytes('0x548de65b9c13426fc3d5da0b95bbcfd0d11dd1f9721a479a0c8626bd99814567'),
#   HexBytes('0xfe0610d329bf49b28c5dad45fcdb9d555d0c709e30018b7fbdd35e32320eb9b7'),
#   HexBytes('0x1cbb15810a1196f1c9ae0b30b3f952ef2a28baf07ed74892e8436158a73828f7'),
#   HexBytes('0x9737386ed94baafde489d372a127ea4cf8f91769d9e7bbe3f1fb355d3c02dd9e'),
#   HexBytes('0x0d9698115eb48bcdda3369b4e39dcc4ac9451ef858a48ec88611435185868334'),
#   HexBytes('0xee2f2a7c0a0476621eb181eb24e1d934d3658c17753c6ea17f4186865b67df64'),
#   HexBytes('0x8e8283b85ae8110eb5c4a4d165e5c1232f84296d17676c7036c6875ed6eebda7'),
#   HexBytes('0x1452a07a96282423c8c1d08c697e9a7aa2cd72880d1d8c8905a170e569bb5b81'),
#   HexBytes('0x4719be13c45223828016c753f873e3c931104fef380feb7423720c72b3df8cb4'),
#   HexBytes('0x5401649270922e24c1bf88d511ec37d644ff4e905ef1d79c97928c01b6994d2f'),
#   HexBytes('0xc7ef8f5c88aeecf3130235920e60845be3938aafd95f69420bcb3f6e851e495c'),
#   HexBytes('0x42107674273411c218de200c79bc782b424887f8212ef36265f3b4236b8d59d2'),
#   HexBytes('0x2985bb47e776358d0add177bfc58ad9108dab478531e25a06526dd273edd3c38'),
#   HexBytes('0x538f9a7c4c9a89449c47d2972c2ea2c98a88aa847ef21a049f4b55822243bda1'),
#   HexBytes('0xfcba0c95225551359d0d912ed9b093df4208557cc32bdde1699ea1860a6cd8c9'),
#   HexBytes('0x68d1ba93b3e385b612c48954a74a64c4f65bc15fa11a319cb6c3952e03a029fa'),
#   HexBytes('0x79e44d11d5ea5dfbf29697953e3d013a2ed76fbf478f1e65863664d54b84dfe9'),
#   HexBytes('0xbf115e5a5bb59c3004bd7080a93dc6410e10c9a7c0a0fef4e86d0da6819c7005'),
#   HexBytes('0x715b3bb4ffd2b9934e73ec7c6131c911dd79bfb4c301a50b9614edfd282a7eef'),
#   HexBytes('0x22cb4d6ef1f8af23ea311ffe77571ffdc9e74c5275d72f6d2cbd6adb2f4890f8'),
#   HexBytes('0x26c0d44e9aaa0aa4c8c8da95d8f73a207c8ed7edb4d1b3545653c031c47720c7'),
#   HexBytes('0x134441034d21619017dec48a5d6757e7d221163c05abeb1a060edba2dbf08c32'),
#   HexBytes('0x318e7f37e000a6517fc1b8186c17ce0813d6d6290fa209bea34268c740213530'),
#   HexBytes('0x759786c994e1df13d836bf48d5e7ce46d2cdc7beb6810bc6af4634fc425e23ae'),
#   HexBytes('0xb1e0be65c530140c9ad341b92703f3142e81a5a80f07c223240aabbfd160e897'),
#   HexBytes('0x76404b7acfbadb14d392ca2e44104fe5faf0493198f653b9aefe4a9c6b006514'),
#   HexBytes('0xbf4ad788b35073d9cf52c59e3ddefac92e6924f9d6765f62664a8d711a239f82'),
#   HexBytes('0x6c140e2d97b57089955947cf8ca1a08fd3ab05ca627dd8194bd7b575ea3bd63a'),
#   HexBytes('0xca2f6d83fb979d83ffcaf9bb9c4308703b34621d81517cdf0a03f118ded43d29'),
#   HexBytes('0x2a06a7d983f080e4c41899c7fff09eccfa4a1637019661f348d2f10d142c0922'),
#   HexBytes('0xf375bc8006d7fca170ec4cce661bec0ee7cde667252338da7bda85f95e0f30f7'),
#   HexBytes('0x23c612d17ce153e22d24df96383435d3b301cd28e50552006dd668609f522315'),
#   HexBytes('0x2c723ff7ad7ec9d0028ebb467eee38ac8bd004c10e8e7a997920d1d08a4604ea'),
#   HexBytes('0x75377834f11000e7788a353133434e870907e5c5d058f4147d6587740d700ab1'),
#   HexBytes('0x02fbb833f904f2f8bf7415f591e5d7c56cfbdbbf636b28d5c4346a22ccc86bbf'),
#   HexBytes('0x238380c3f6e38fb696448234ea189c4908e2421e68340a5139917c676daaf672'),
#   HexBytes('0xf4c6ff4a86035ef889dd5fa8862801cf55518f604921c9e8dc92c47d152ddc25'),
#   HexBytes('0xee9d464062b9ddb069aa0dc20da5f24ff9d7018c2f37445b14c1a7ddbf16492c'),
#   HexBytes('0x8acb3a35a652688851255fc320f0ecf0eaeac5d4c11f3e1fbb34f3542ae67919'),
#   HexBytes('0xff7be42ae79e0703e6e991cacd6b36a062cb7a64ba61b6373fcd0dce31640750'),
#   HexBytes('0xdc50de17f8290fbcb830430945ba566e278d837036fcb0e3c520da58b7d2e9f4'),
#   HexBytes('0xda8d1454e7b63569eeead855f4284320eb90d700ad3e2dce1be91b984b0bef01'),
#   HexBytes('0xc86013bcbb0fadc13d05b3c998b940399a1077f7362303d92fba0fe9f4173dae'),
#   HexBytes('0xb3eac0b928f64d5ffba90036c7ae08c94b160db912088886b2347c9c7e7c661c'),
#   HexBytes('0x71daec8e0a68c1936e15d65a6e21a44466f86663c637018f46bbb12ac9a10424'),
#   HexBytes('0x6a3f6b2a791ea871c69de37f568eb720c823725724a4b8ba737a8f4b9effc66f'),
#   HexBytes('0x5c2ba9cf9be477d8efd8b3e4a740e11e492ea4ac3c24d7b1be65a93682f1e07a'),
#   HexBytes('0x5667ffaea51e4b7dc075a0c7881daa273c89f0af343a88cb814154aa92089c6a'),
#   HexBytes('0xe2d7ddf2736ad38a06cd04f144d7d9640bf37e0de7e9ce7201ee23fe5a8a2b1b'),
#   HexBytes('0x3dcda478f75c0e9332f37c5df006d6e77d2b45832a0a04618f58c0d42dea322c'),
#   HexBytes('0x382d00dc449b82a1e876344656cd75915536081fae794d7a66d4548e95afe9a7'),
#   HexBytes('0x288a93ff7f5028851e8decd3fac0ca84086149a1cd40776532884b27cf6ac539'),
#   HexBytes('0x25233cab9b77d337d8a75a7628dbf206654a942f898937e38dc307168eea79d7'),
#   HexBytes('0x0993aef2d499c1b987375f675bf317a2c8e1370cbcaff01c643593cd25b8d502'),
#   HexBytes('0xc2a2ee1e74e136edd28dea322288291eaf826ad1e1591569aa2be724b71d50ac'),
#   HexBytes('0xd3bfaffe22bdf4149db5ac4b81485be2e1d7e77be96cdace945b2afb32b45411'),
#   HexBytes('0xf350d923179a186fa3366a54e9bc7a0e9fc1c0e61198688ba2226936a84278b9'),
#   HexBytes('0xaab5c380cf16d3afa23d36c174d2b9cf2d9cd64441dcb4e2cff8e75ff0c0fed2'),
#   HexBytes('0xd7afebc48b37e2ca44422e36796f785c6613d317e23e1c5b95da255e581ea072'),
#   HexBytes('0x05f03225ae955312beac9fe6234a424861a5f82cd26cf8bdc92bf52416db4eaf'),
#   HexBytes('0xdc4f6573d201f5b41f436ae88d605014bc3d98c4f46f191341cb316e87da8a2e'),
#   HexBytes('0xab9b7026810dd8eca4e5818e1df63c598cd8170527d16efc61a3244f557a0692'),
#   HexBytes('0xddaf8353e08a48aec95ce9c275342a0e24cd3a0822f3a6ad547ac40de9560dcf'),
#   HexBytes('0xb5f843606f8c9143d88afda78faa920e888a537632f3951babee85fd25b2fd9e'),
#   HexBytes('0xabd932e7ade8be1c6f963cd2d5cf83b7bb6fbb677ee084964e8064e9e41e72c9'),
#   HexBytes('0xaec7aa69db0d9953fab467e67212432edf9baf1c8ead223143f2f2913840570b'),
#   HexBytes('0x7fc9b2e3781277f71be5186a7714a5d0a34d4ffa61f8a57236bbac855c894713'),
#   HexBytes('0x74d89fa8d0ed9e8a5589f7a3f8a8de4dc6efafba8f3a953809ce314ca24eb8c5'),
#   HexBytes('0x678c008f56b94ad3c221dc8b5fea2a0ecde00adb26da90e516d0c9e211cd25f6'),
#   HexBytes('0x639bb55404ff0720032f05a89cb80da925c5d9a1e3b3299c3ac6be3ee34b80c4'),
#   HexBytes('0x5cfad5d332a062b699638850cd3f1e4c6298b33cc0fd445f5f74efd386928245'),
#   HexBytes('0x9c589f3659023d257989ad29832f81e5ed8860e543e6a78892fb505dd7f82202'),
#   HexBytes('0x29f83ce89dcb7463a057e772696b4423bf6136de3ec77982004f49cf1dfce30f'),
#   HexBytes('0x4e47de5d3a29f0c3c51d50b96715ba853906801f47fd95ae011b27706ecd1a62'),
#   HexBytes('0xbdf0bc9af32818efaed503c248d31a1c3426d17e7e94166ea35f89c50e96f9f6'),
#   HexBytes('0x1fe9fc79d6758c95f9254727ff6b0740ef4b0a63fdc8ad7dedfd25a5efd4ab76'),
#   HexBytes('0xcd359a8afe2049c0b3a83ca3d221e6ab9b628d3441fc06ef19decdd0145cb08d'),
#   HexBytes('0xbf22d24248345318a0b32074544326dbec826c8ae78073148e780035caca5c7f'),
#   HexBytes('0xe399eac0a97e933824ba2f94235483da1c0008cae27dfbb083ad13febe46830e'),
#   HexBytes('0xdfceb4a797e70ae6a9d7941d69507d3bb7d2affa6ad5022709b917eae3e9b884'),
#   HexBytes('0x23e5472d54a882dc97d1b3404b86edb0bf537b972a7b670e6f455b98a1168870'),
#   HexBytes('0xbff7ef6c9e4a023cff2425c4aed449e27d0e6c08cf71bfae8f3dccadb320e3ef'),
#   HexBytes('0x8559ca816ec3e8d818ec3b692695d9f3d1dbcc83232a78b58ff520c39620d6d3'),
#   HexBytes('0x8e18793d863c9b1eb42eb2abd52f7e7d5d6850c953a4c4fe208ac5aa3ed85fa8'),
#   HexBytes('0x8240ef4363739554ac8380e34cbd6bfb09561520bdf3df2c02d57633da62f45a'),
#   HexBytes('0x813885e5aa3642a74320e4f797308ecdf4fefe1335cb5070d8cdde26411b4627'),
#   HexBytes('0x78317c3bc51cf801b1ac5ad1a5fc1c1f3e003334e51a7cac38ebeab1766bdccc'),
#   HexBytes('0x70e00366b302f05f39326b8f9589bca68af4b3fe8da0db9232aafda51dc4e6f2'),
#   HexBytes('0x4c7f11b29380e21d18a452c9bd5e660a54bf1dfb52948ef26df611f54d9dbd24'),
#   HexBytes('0x49c7ceca20da6b8b1f04b4ed656b22df49d07c28fb9aac794cae6b0d2e268498'),
#   HexBytes('0x3096b5a4f0b3984de026b0897bf0a3ebdb248cbd6fe4e194beec7f554d1e5048'),
#   HexBytes('0x24ff89aafe5f2af3e8461db06cbe963ef3c2890afe86e67182010f91d6ceef7b'),
#   HexBytes('0x38f01e4e48021496c58fe7ee29e830593542bcac1c6e64c0e5ff1b92d21b2cea'),
#   HexBytes('0x07926d88c2a54dad6bf5efeb53f58c51713ed31a386fe74b0c4dc1180fe15e7f'),
#   HexBytes('0x62ad9df4f4f8cc93ef2914441732a1cf29e29f5950a96bcff28169d593fea1db'),
#   HexBytes('0x27845ed1663a3b899852b730d4f0a38497a82c7bc0ea2bea44f48d14a411ae18'),
#   HexBytes('0xa466f6bd9202a454a0016a86f0171cd9497b1830643bb59d299acbb3b1ed949a'),
#   HexBytes('0x8ce13e67cda4d909ee254cf7c075c046e125d915e26578d34c4f6ca38df61b88'),
#   HexBytes('0x40f6d231b0e9af7a925472589b30147ce78f818eb7eb1c2a1cbf22928224cc2f'),
#   HexBytes('0xdf78152cab8fe3b4e3899ba30e8d9bb19921172674b1b6604b619678ea7afa66'),
#   HexBytes('0x53131d001b27e129cd74eb339a6cf3a764e4c76907a9c9ab2b65f303b57ce44b'),
#   HexBytes('0xc7c616c8bb643fef3e1d0e39e2ae0c9c6ee2996216280d309f93c8810f6265fa'),
#   HexBytes('0xd052fb4bea08e28c97ad033fc06eff275e094d9ea2de2d2795979701b9f43796'),
#   HexBytes('0x5a9286875b210aa2bd0fb9e898fcb7fd74dc8e5ee56b9729089813a0965fa7b8'),
#   HexBytes('0xecd64bec4d95762830f43019c6cb15c634f4459b98875f4177b481b7981c3587'),
#   HexBytes('0x43cd4ea4b5c1ff168baab8df932a5272211f4443b805cc5356e2cb45b9a8d0c3'),
#   HexBytes('0x67f685ef975d48099ab47f8e5c642bd486458925a3002e643ec4343469052ae5'),
#   HexBytes('0xc6a53a31d93e48f8258b290d1c20495b181148ab7c930527284c1ae67b0cbc0d'),
#   HexBytes('0x855df169f1bc5857a8b4e13dc88548f83f25d0277bc99942c80ca62b0f5134ca'),
#   HexBytes('0xb26ea063e802a0b383799b7797943d2c2d6070ac9b42e00a6169b6fb0f6aca1b'),
#   HexBytes('0x4feca09678a35d89553d28ccc89d35ca3549948ee63b1cba03a42ac660414ea3'),
#   HexBytes('0x845492623d0fbdaef66286baefd3040066992987aa35f2ff3b7280ad49846dce'),
#   HexBytes('0xb01a8effd37f92c083304d8063a1baf4120159a828aaf91a8f3a7b4d26f99fe1'),
#   HexBytes('0xdfd88d4b7362581ed74783debdba697e931ab17214ccc9bdcc1e09d93773a235')],
#  'transactionsRoot': HexBytes('0x3397fe7a221a5beaa73c7faab3631020fb78e60b1b55cbc62937e38583efabe0'),
#  'uncles': [],
#  'withdrawals': [AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 109998072,
#    'index': 105757627,
#    'validatorIndex': 2021458}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18092578,
#    'index': 105757628,
#    'validatorIndex': 2021459}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18074638,
#    'index': 105757629,
#    'validatorIndex': 2021460}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18104112,
#    'index': 105757630,
#    'validatorIndex': 2021461}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18083789,
#    'index': 105757631,
#    'validatorIndex': 2021462}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 64831112,
#    'index': 105757632,
#    'validatorIndex': 2021463}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18068138,
#    'index': 105757633,
#    'validatorIndex': 2021464}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18061713,
#    'index': 105757634,
#    'validatorIndex': 2021465}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18100098,
#    'index': 105757635,
#    'validatorIndex': 2021466}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18095283,
#    'index': 105757636,
#    'validatorIndex': 2021467}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18084313,
#    'index': 105757637,
#    'validatorIndex': 2021468}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18053594,
#    'index': 105757638,
#    'validatorIndex': 2021469}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18082186,
#    'index': 105757639,
#    'validatorIndex': 2021470}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18093064,
#    'index': 105757640,
#    'validatorIndex': 2021471}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18071437,
#    'index': 105757641,
#    'validatorIndex': 2021472}),
#   AttributeDict({'address': '0x0b26C05866e6353E46f4A7e2d10Cb42d4B583E57',
#    'amount': 18093267,
#    'index': 105757642,
#    'validatorIndex': 2021473})],
#  'withdrawalsRoot': HexBytes('0xe6c70f7dbbfd8647c8e7ba2a2031d37ca9bca09bee039f72e176f5a632f72756')})

# %% [markdown]
# 下面是**以太坊（Ethereum）区块链上的区块信息**的解释：
#
# ---
#
# ### 🔷 一、基本区块信息（Header）
#
# | 字段 | 值 | 说明 |
# |------|-----|------|
# | `number` | `23644435` | 区块高度（Block Number），这是第 23,644,435 个区块。 |
# | `hash` | `0x69eb...7667` | 当前区块的哈希值（SHA3），唯一标识这个区块。 |
# | `parentHash` | `0x2690...07c3` | 上一个区块的哈希，用于链接到前一个区块，形成链式结构。 |
# | `timestamp` | `1761273923` | 时间戳（Unix 时间），对应 UTC 时间：**2025-10-24 10:45:23**（与当前时间接近，合理）。 |
# | `miner` | `0x4838...f97` | 出块矿工/验证者的地址（PoS 时代实际是提议者 validator）。 |
# | `difficulty` | `0` | 在以太坊转向 PoS（The Merge）后，难度为 0，不再有意义。 |
# | `nonce` | `0x0000000000000000` | PoW 非ces，PoS 中固定为 0。 |
# | `mixHash` | `0x44e2...06d6` | PoW 相关字段，现在无实际作用。 |
# | `sha3Uncles` | `0x1dcc...9347` | 叔区块哈希，此处为空列表，所以是空哈希。 |
# | `extraData` | `0x546974616e...` | 附加数据，十六进制解码后为 ASCII："Tian (titanbuilder.xyz)"，可能是矿池/客户端标识。 |
#
# ---
#
# ### 🔷 二、Gas 相关参数
#
# | 字段 | 值 | 说明 |
# |------|-----|------|
# | `gasLimit` | `45,000,000` | 当前区块允许的最大 Gas 总量。 |
# | `gasUsed` | `8,951,783` | 本区块中所有交易实际消耗的 Gas 总和，约为容量的 20%。 |
# | `baseFeePerGas` | `316,260,888` wei (~0.316 gwei) | EIP-1559 引入的基础 Gas 费率（每单位 Gas 的最低费用）。用户需额外支付 `priorityFee` 给矿工。 |
#
# ---
#
# ### 🔷 三、状态与默克尔根（Merkle Roots）
#
# 这些是用于验证完整性和一致性的加密哈希：
#
# | 字段 | 说明 |
# |------|------|
# | `stateRoot` | 状态树根哈希，表示该区块执行后的全局账户状态。 |
# | `transactionsRoot` | 交易树根哈希，包含本区块所有交易。 |
# | `receiptsRoot` | 交易收据树根哈希，记录每笔交易执行结果（日志、状态等）。 |
# | `logsBloom` | Bloom Filter，快速判断某日志是否存在于收据中。 |
# | `withdrawalsRoot` | 提款操作的默克尔根（见下文）。 |
#
# ---
#
# ### 🔷 四、EIP-4844 Blob 相关字段（Proto-Danksharding）
#
# 这是 **EIP-4844（Blob Transactions）** 引入的新特性，支持 Layer2 扩展。
#
# | 字段 | 值 | 说明 |
# |------|-----|------|
# | `blobGasUsed` | `786,432` | 本区块使用的 blob gas（约 768 KB）。每个 blob 最大 128KB，最多可容纳 6 个。 |
# | `excessBlobGas` | `1,572,864` | 超出目标 blob gas 的累计量，影响下个区块的 `blobFee`。 |
# | `requestsHash` | `0xe3b0...b855` | 请求列表哈希（目前为空，即 `keccak256(空)`），未来用于 P2P 交易广播优化。 |
#
# > ✅ 这表明该区块包含了 **Blob 类型的交易**（常见于 Optimism、Arbitrum 等 L2 提交数据）。
#
# ---
#
# ### 🔷 五、交易信息
#
# | 字段 | 值 | 说明 |
# |------|-----|------|
# | `transactions` | 列表（共 128 条） | 包含 128 笔交易的哈希（Tx Hash），可通过 `eth.getTransaction(tx_hash)` 查看详情。 |
# | `transactionsRoot` | `0x7c69...1145` | 所有交易构成的 Merkle 树根。 |
#
# ---
#
# ### 🔷 六、提款（Withdrawals）——上海升级后功能
#
# 以太坊在 **上海升级（Shanghai Upgrade）** 后支持质押 ETH 提款。此区块包含 **17 笔提款**。
#
# ```python
# 'withdrawals': [
#   AttributeDict({
#     'address': '0x210b3CB99FA1De0A64085Fa80E18c22fe4722a1b',
#     'amount': 18081897,         # 单位：Gwei
#     'index': 105751579,
#     'validatorIndex': 2014771
#   }),
#   ...
# ]
# ```
#
# #### 解读：
# - `validatorIndex`: 质押验证者的编号。
# - `address`: 提款接收地址（即提款地址）。
# - `amount`: 提款金额，单位是 **Gwei**（1 ETH = 10^9 Gwei）。
# - 示例：第一笔提款 `18,081,897 Gwei ≈ 0.01808 ETH`
#
# > 📌 注意：多个提款来自同一地址（`0x210...a1b`, `0xB23...C93`），可能是同一批验证者或同一质押服务商（如 Lido、Coinbase）的操作。
#
# ---
#
# ### 🔷 七、其他字段
#
# | 字段 | 说明 |
# |------|------|
# | `size` | `46,134` 字节，约 45KB，表示整个区块序列化后的大小。 |
# | `uncles` | 空列表 `[]`，表示本区块没有引用任何叔区块（在 PoS 中已废弃）。 |
# | `parentBeaconBlockRoot` | 指向共识层（Beacon Chain）的父区块根，体现 PoS 信标链与执行层的耦合。 |
#
# ---

# %% [markdown]
# 如果我们要构建一个像上图所示的 Etherscan 那样的区块历史记录功能，我们需要获取链中最新区块的列表。我们可以先获取最新的区块，然后倒数，直到找到链中的最后 10 个区块。我们可以使用如下的 for 循环来实现：

# %%
latest = web3.eth.block_number
for i in range(0, 10):
  print(web3.eth.get_block(latest - i))
# Out:
# AttributeDict({'baseFeePerGas': 107648489, 'blobGasUsed': 393216, 'difficulty': 0, 'excessBlobGas': 0, 'extraData': HexBytes('0x546974616e2028746974616e6275696c6465722e78797a29'), 'gasLimit': 45000000, 'gasUsed': 32574881, 'hash': HexBytes('0x92ea1c058f8de1080f6f18847d6af678279097e05fac09062e382de3597e039c'), 'logsBloom': HexBytes('...'), 'miner': '0x4838B106FCe9647Bdf1E7877BF73cE8B0BAD5f97', 'mixHash': HexBytes('0xe7347428d35f436c072780dbaf2b1c71661c87c6a5a9ff1299912bc392dc59c9'), 'nonce': HexBytes('0x0000000000000000'), 'number': 23644814, 'parentBeaconBlockRoot': HexBytes('0xcf043ce03dcc86bfd56bcc6656c57728cdd1412882503c41ec64e74ef4092d53'), 'parentHash': HexBytes('0x0789473cf3dfd0b0bb9a2e62b00a8615ce4c122677bd0d1f3fec99bd93460a41'), 'receiptsRoot': HexBytes('0x4d2bd840d4644a95ce00a8e19b30a66db1c2b3a139f5f3e824a5189714e778c7'), 'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'size': 157489, 'stateRoot': HexBytes('0xe20a141f0c571e2a9a5c8a1a0cae89d7fefdbea30f3350ef1489691658321d6b'), 'timestamp': 1761278507, 'transactions': [HexBytes('0x90baa300ae8e68394267fece9f1af963951951a568cb4ba2613e84c65c9a79e1'), HexBytes('0xc9b9e751e991f049655452e3d643ba7daf25a5c10e29b98d71fbc78f1fe8dacd'), HexBytes('0x27126ac8afec2410097894f612c82c472e2a38d8ea8ff398551c1caa27dee4c4'), HexBytes('0x6e31a0a82e96c7ec4bcf8ce4c1ffa0871b4249e39de8b485c7e61dc2a1d40415'), HexBytes('0x877da4ebb52d79b9c6a58b36d33eabd7bde72f5b25e035732cb372ad1a7880e3'), HexBytes('0x6532764bd37e644160a8a465c7916a71023c5bba3d88d20d67f36b7c793d1b17'), HexBytes('0x4fd8c4110a1539e98ed715c6d40bce28179a4d0aa0f98b77d198dd5df0299671'), HexBytes('0x5d1a33808730e1f6ea92a6f2a900792ace919678c339d15e4a90a91f8e98c091'), HexBytes('0xcecd9f8f98ec7a3d08a412b356f9d91229db0bb36fd39d9144ccb75616d004a6'), HexBytes('0x2d490488b66b48cdbde7a3c418770680b1ff4f6a2a7fc7ba816df527abdb5b21'), HexBytes('0x28ea220c8c10913258dd9a0b4485ae1f43d73470f1aac56b3a533d3bb2e33a35'), HexBytes('0x814283f52757346c882709577ace19a234ec6ced960ef933f60c048e4f177e7d'), HexBytes('0x66f79f52818c4cc9fff7dfa507d11ecf4c03d6f3fb897393df3fffed5ad9339e'), HexBytes('0x88c8dd4be4c3901323d74155afd59f431e3e3e3249f1f1fc39f58856f1cb2a97'), HexBytes('0x3e8ad702899f9fc0c1f9cb9b3eef07d88d453f386a4603d391f7cd37341bdd9b'), HexBytes('0x7c0bd7f6fb1b69463c0d9d3f139fb5692ef77b5cc4124168bedf362857368388'), HexBytes('0x8ffed38ac354bef4e9ef94e92cf9a9b758944f1f64ae4b816f22e318fb83d3c6'), HexBytes('0x753df13842f306111ee4fa66523a7ffb706c88ab195dd31bb45d4dfb3c020659'), HexBytes('0xd70c880dc471bcabf5776b288b84c78e16aa5a0ac065ad7bef92a48886fc79f9'), HexBytes('0xbea003bde311d9870181a4d08e2a7852855dd807e6610e626860a9d3540f7b35'), HexBytes('0x54799283ff5b4cab2936578c64cadf8079c19e87b16c5ca18d3ac9dca34563d9'), HexBytes('0xd49d73e9abe093e39cb0b1e4bd8078abf8823e7cbc06679cf6219dd142def4be'), HexBytes('0x201c6ad7b71aa5d203fc7b2bf7af0791a471c811c7b35c1ae0fe817a66476d2b'), HexBytes('0x590b5d95edbfc671fa77d6a8f04cf88225bce53ed1c4df638c241ba4777378c4'), HexBytes('0xb6108896aa38e19521158e3f1fdf0f591459835cab7bdbdb58464e8f9508923b'), HexBytes('0x27ebe594ccb901bbc368928ef7391b090c551518089ca22c183fdaee198fd775'), HexBytes('0x90de0ee6a053c718927021090899c6f1de53456d9150ce1b217ddd51099e9d9b'), HexBytes('0x00750398c85fd1f334685896c312932dc91c6bc0ce40e418fadb65b8c17dd988'), HexBytes('0xf464df99e22018afc00cff9e050511e4c86ffe9019179c0a5a43145cf3f406ad'), HexBytes('0x73b1bff584b8af5b575520cd20eee45313a92523032e4e8af120bdfdf0e990b6'), HexBytes('0x80df5a04e94da73989fe43550d026fbf02df9a546772b9b047d0411117bd6b75'), HexBytes('0x9c17325f7256ad951fc8f61012afca6cc8df78d3b25b11b2aab28d16032f3c16'), HexBytes('0x39b19f8d1df288ab8c97c31695fd2e85f9e4ea83e284229bd3f0684e6f10f495'), HexBytes('0xf441bb925ec522626c73b9f198d6b415b85a711a42c98fbf7c72ccf68f645183'), HexBytes('0x17feae7f3b7289567ada3eee1601a9f8bcbafaeb04864c80a758719566c4a244'), HexBytes('0xe556 ...
# AttributeDict({'baseFeePerGas': 98176494, 'blobGasUsed': 393216, 'difficulty': 0, 'excessBlobGas': 393216, 'extraData': HexBytes('0xe29ca82051756173617220287175617361722e77696e2920e29ca8'), 'gasLimit': 45043772, 'gasUsed': 39905046, 'hash': HexBytes('0x0789473cf3dfd0b0bb9a2e62b00a8615ce4c122677bd0d1f3fec99bd93460a41'), 'logsBloom': HexBytes('...'), 'miner': '0x396343362be2A4dA1cE0C1C210945346fb82Aa49', 'mixHash': HexBytes('0xed43e9a0a48a5fa125681adb03a6c4e3590e58b11986d1c3ed691974a1c6dee9'), 'nonce': HexBytes('0x0000000000000000'), 'number': 23644813, 'parentBeaconBlockRoot': HexBytes('0x1c365e94c3fd9e7abdd86bdf69b83507dccaa1bebf88ffae504239002798e91f'), 'parentHash': HexBytes('0xbab3a1dd833a5d9ea01cb52dd7a88e03e3c9f626ac7c4c93f3be242f3b673957'), 'receiptsRoot': HexBytes('0xca0ae41cd8279c83023294d125cf8f672ac16e82d7aaa241676518ee08d4ef84'), 'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'size': 101261, 'stateRoot': HexBytes('0x663860cf65ecdb107449940ce3b0353fd58eeef37df8f18b86579323b8ff246a'), 'timestamp': 1761278495, 'transactions': [HexBytes('0x64b4a2bb72487e2ed563bbbccc844caf4a12e2ce3dfd9d98d49d74ab7d50103c'), HexBytes('0xfbe83285263d995ab25c8b089ef989cf972d409388731060b260eab0a276dbac'), HexBytes('0x5105670c38a4f27e061d1380eb558c6f1a16c20d9a9baf75511f74c01f22f205'), HexBytes('0x8161caa1f92afe0d59856507f4db8be66f33a7a7e777b0d3729fab0228b27c86'), HexBytes('0xf91fc67d10618c9b7675c2ab90822d27f3f5007cee2eed1d77568dfb0e5bcbf0'), HexBytes('0xea0220b644ab67a4e817d8087ebf24a848cb85bb1aec5ab34d2668c2156bf582'), HexBytes('0xe1bcb76eb85ba2f256541494f7c8767037c4a15a9dacb001241edc834aec7ced'), HexBytes('0xc7d93942d64df8b3b7d591020b1e67faf958e38133958165982cc97c8a665fef'), HexBytes('0xd0f2e98ecc58601b82cb58680c4988ed5cf219ae0fe1992aa626177aec0f5f93'), HexBytes('0x311a40f351093c56c26b40cc127444e078cfc1713b523008fbda5f3e45495975'), HexBytes('0x58bd4a8fb2120361080539ee5d1f0537ebf154273beb9e4e4ee81c572f97e6d9'), HexBytes('0x4abeca00c2ab6ac07982096a2a781b16e3e1b627d5955ea5891efe4935958b56'), HexBytes('0xc396274be1eda94a5a359bd7567f8e2630d6edaf46dfb83b6742c309ed7250f4'), HexBytes('0x2fad42e4d0c712765e0c8b0c273d611370e9626076d3c9e84cb12fd89b112621'), HexBytes('0x1c616432bec02aa164411f23f714951c2d4ee15e196a4d2c63fc62a559354877'), HexBytes('0x0040d368fd0ebdcd500b84244ed3907bea93a9192d83c4f9c97700d467c6ab71'), HexBytes('0x3413415d639f850fd21b98e529f9c64ce91edbf51edd9dca79f8aa617f00de84'), HexBytes('0xa29863dabeb776b7097998c6339cfe07a6021771db45224a672acea13dd97c2a'), HexBytes('0x4ffc1a21d2328f0332f9df4560f3dc2d8d977086d4e4773695b3700f02517713'), HexBytes('0xa90518096b58a8f01a33706e6e36d81d0ff2d21454717659be276741eb3a5b77'), HexBytes('0x2cd120f54eb35f455c7c04f4df728c60e1137b2d19f8875004e05cf7dbd71602'), HexBytes('0xf16e40db3cc7c7b7204b97472e31cb6f867f547d155a53deadf0ebe52e8594ad'), HexBytes('0xc797e680159e268146c83dc6e167d2d221d78b14ce27372090010bc3108c2b67'), HexBytes('0xbc24c4b6e3a98142e19512d552ddf16b402e1e2bda02811a1e3e5a7c4ee7a42a'), HexBytes('0x9994610ec174c1acca7eff022d346b5a373f88193aec5f17ca2dab2849498bec'), HexBytes('0x8d713f9daea953273d8623c32f113cea5924d1b3d447f0fcc9c120fa226a18ed'), HexBytes('0x371a383c20b75c9ad21bbb029c8a1d56b2f233d0b43a79e1e5695bc27a931c49'), HexBytes('0x3021a8189a3954c7db070b969c90666cd82b17cd157bc55287d1f9e91cb057c9'), HexBytes('0x03d0161471c9c77ab84969be730fd1d3940d0154284b2307aee1b439c3456321'), HexBytes('0xf594f4cc83ad4082decc7ea59103047f64aa119d30c58237c1efe7a034fffca6'), HexBytes('0xf05529a301c686509c5ad4e78f9ce73eaf6dd380382a8745085043d4db79ef69'), HexBytes('0x799173b2ef7912fd88335d0025889289927c4470647aa771f8f5aaf24fd874c5'), HexBytes('0x44491397475ac6ce710e76c1c9917f4d3514ded8bfc8de33111ee00695d8ae34'), HexBytes('0x28c6cacb1468fc06d53b183ed6d7facb6868c861703ad0ca2e2a3c8c4b7bef95'), HexBytes('0x21103f370923d890f6ab96c8892634a9567822287256153844fe836d72ba757d'), HexByt ...
# AttributeDict({'baseFeePerGas': 106871635, 'blobGasUsed': 786432, 'difficulty': 0, 'excessBlobGas': 393216, 'extraData': HexBytes('0x407273796e636275696c646572'), 'gasLimit': 44999828, 'gasUsed': 7855060, 'hash': HexBytes('0xbab3a1dd833a5d9ea01cb52dd7a88e03e3c9f626ac7c4c93f3be242f3b673957'), 'logsBloom': HexBytes('...'), 'miner': '0x1f9090aaE28b8a3dCeaDf281B0F12828e676c326', 'mixHash': HexBytes('0x00e1a625d7b9a0c34e3d1e3b929d84b9e15fe2155511765666c7f3a1544218f1'), 'nonce': HexBytes('0x0000000000000000'), 'number': 23644812, 'parentBeaconBlockRoot': HexBytes('0xe1ced7055339882c0c501f57f2031008c790b22467b370684f9aea09c87063e3'), 'parentHash': HexBytes('0xad2aa8b4553e6b0b8cb47fe76653148392d3adac12c8bc6bde59431239006deb'), 'receiptsRoot': HexBytes('0x117ccd84c8a2ed9abe80509fa51eef8cb0835f593c61b35264a90c0c083bd254'), 'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'size': 42184, 'stateRoot': HexBytes('0x1643539a296379e593720973deed376ea2bc6e20899a14cde87284a424d6c922'), 'timestamp': 1761278483, 'transactions': [HexBytes('0xd9edbfd668d0bbe8f43947c6564d29ec58157d859563ae1a33e7730d8f417106'), HexBytes('0xec4d4557e595b829ddf0fd28102dc9ece8d7cf81395c200fa9e3a579f2634ed9'), HexBytes('0x355f059e2a86884ec8187f5b7578cfbce38236d2de9c324cfb719e2d56dff572'), HexBytes('0x7222f8be0c6c7e90b12a5d08d7b1a785b1231ef1ca6358e0cee5fb0a378b90d4'), HexBytes('0xf62aac8097f3c42807b108c8a2bf1cb69a1e3581118bbc9396bb4575ffa1aa15'), HexBytes('0x056e6e51910c415e485bde1cbe2f2deca1929fa4c8447f1c58ae8ed9cd3f8722'), HexBytes('0x093774cf3285122f1ffd87039ba173942dc02d698414adeef2ac6a4111341409'), HexBytes('0x23832183f2e8c024bf3d3ba9e997e760973efa32f9dca971bb20d290d11df58f'), HexBytes('0xa6396bdc5371c2f2c7bbbdc69967574a99318ac4a27529237464382e62bcc837'), HexBytes('0xb1876c110a9849eadf096f60b54f48522f3a6e158b1770d33dd4b74a989a60c1'), HexBytes('0x19d8b1ac3adfdb1e9f23cfedb8d1a7617cb5fa5a88af72dc24a2d9335244f398'), HexBytes('0xcf2e5e256b4823c0264788ec976338cfd33bf3e9725bde8e92f14f0cb0c7c6f1'), HexBytes('0x64d3500751db393fd07fdde440682a06e525f415d2d66fb6ad8b44943b09eb14'), HexBytes('0x9e6c536c1f9568080343e5ae38761bcac7aa19492d81452138652f130e82647e'), HexBytes('0xcac03d4ff3945d9abff67dd4fbd677b838c8647e49b6bdea03f6279f31047671'), HexBytes('0x025b467a7dd5f0171baf0aacebc1f469fa451f9a18f4cda1ce41fe4e59f3c4a2'), HexBytes('0x17f65d3ee6772be344b38ee7fe510c1aacf1ea0d85182d6ef1a57512c08b4dc8'), HexBytes('0x20580252101d11f2b0fab64aff6d7ee391ecfd9f18a4dc79862266cbc926ef32'), HexBytes('0x2c595f454d228683900aea5ba6fb3cb43f48f4aa3e4cbc824ac4ec244aa9a991'), HexBytes('0x6d75d27ff7dbcd712da661701fdfb446774feb836f14c0cd203c93a3603eeea5'), HexBytes('0xd5353a4e3e8dcc6e8406f92e34a4231c496eeecbb6c71f78e3a7f7b5179a9af0'), HexBytes('0x4408f3e727c544389ba39a141e7fcf3260985094c5c9842c6ba25800ab61eb91'), HexBytes('0x80e4e2f547868403ec4b25034a94050e7c81a76701e24505e6afeaf418bc0f42'), HexBytes('0xc0eaa281c1b5f96462005a2951054b931317d435778eeee278d6486adeaa64f7'), HexBytes('0xf2500b281937dd42986bd831d9215bc90c543bed5cc057f722ba6c7cb3592bec'), HexBytes('0x42fb33146be20c2fe3fd1e1b5777f616c2ddf42d107649decc3659b844e4b15b'), HexBytes('0xc056edd03045e9fe09ed03d932ad6bd67fe10ed4afcb1de2f61778c5b21a8c15'), HexBytes('0x74618f07ae02c890cc92e4d477032cabbb611b8e9a404bd26af30443011894d4'), HexBytes('0xfebeb62f323d8c670911d42988970a747757400347774f2e2dd8e66e801116f2'), HexBytes('0x5914d25c8892a69cbf11c5bbbbb3960ad250d654f438c965de420add7f7fc498'), HexBytes('0x5e1c9f1ebde6f632404e23701107a240a01990b5ff0aae96d25803c821cf9035'), HexBytes('0x0efb90897294b7328ca036d2decd60a7603c21ef8ea05b4f4bd8c233671baa90'), HexBytes('0xcca598ad159d65ce8b0e630b5fc62d18b949d8d3bfa55450d03a368da93202c3'), HexBytes('0xf9790a6dfffcde29b8818584a629787022e2785038f7fe1c2e072910f22fcdd8'), HexBytes('0x7bfdee6a6b609b9e9df4aa63f9350fbec0268ca6a9b1b98f83606bc784989932'), HexBytes('0x69e9b0dce85f68655a6893a ...
# AttributeDict({'baseFeePerGas': 105874733, 'blobGasUsed': 1179648, 'difficulty': 0, 'excessBlobGas': 0, 'extraData': HexBytes('0xe29ca82051756173617220287175617361722e77696e2920e29ca8'), 'gasLimit': 45043815, 'gasUsed': 24218414, 'hash': HexBytes('0xad2aa8b4553e6b0b8cb47fe76653148392d3adac12c8bc6bde59431239006deb'), 'logsBloom': HexBytes('...'), 'miner': '0x396343362be2A4dA1cE0C1C210945346fb82Aa49', 'mixHash': HexBytes('0x1d509b4ee485e9ba9c9725b1ba7ff72e76629833ace7b2e8b39efe661c8cc26f'), 'nonce': HexBytes('0x0000000000000000'), 'number': 23644811, 'parentBeaconBlockRoot': HexBytes('0x9b7f27e306ad1dcad0e467cbf54f66326fbea7123d7a969b65940030e4884164'), 'parentHash': HexBytes('0x9a82663ea90f615e03d8f6d3e53afab1f86204f23affc7f7e8484831849f206a'), 'receiptsRoot': HexBytes('0xf9740fe9038bb90bdc0481d9cde7cb0d314523b28a6f0aa5a2029548ce05d1e0'), 'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'size': 104675, 'stateRoot': HexBytes('0x4393cc19d132e832249fb4b4b22d5d9035b8dab0a6d6e80587678607c7c16218'), 'timestamp': 1761278471, 'transactions': [HexBytes('0xc42783b8b695d78e48d1e7a4952c401c39ceb36d3e60b7d3acea6e36c10fe212'), HexBytes('0x3109de42b7396a1458015fd4592c160da4fa2dac4f1848c9f423f523195a37d0'), HexBytes('0xd01b84a2735b821429519dfc5c5524db4e0e3418acb364e7ac514544bd32843b'), HexBytes('0x66f5e9153da2503d6ae6fb184fcfb7d580f9cf4e17ea0be9b2ec9702978963cb'), HexBytes('0xfacffde9a544c9a7fb10b08217d8b371bad53113b1d3b25b69975db92e01725b'), HexBytes('0x139a97280e40a5e8b7b5a228ed321476c9b6b3a474218f7b3bb9de951d5782be'), HexBytes('0x4371368c66800d0b44418adb00dcd080528eef9cee3773e6cebda1916ea3d4d2'), HexBytes('0x80ecb02ab3a7ec9eb9f18e758912226751a1329fad0e3ecd35cde3546ab44bb6'), HexBytes('0x5456c49db8abdeed686683951110d6afef5ab932da0bd49194d2aa1321facf10'), HexBytes('0x872a610fbeb7ab16ef4c7fd7ce9d1c5f8490b27e6981094c960a0c5e6b4d73b8'), HexBytes('0x3369d9eca9b64fd58b530e52e9f5abf62bb8c8b47068c9df542679c02c08469e'), HexBytes('0x3343d32b5f7f8b9824d0fb7b63c47dba8711189d12eea4ce8853ffebc1f18625'), HexBytes('0x720acff53fd53327126de40f7dc1b27381c818201dbda175889ffb80de0a3461'), HexBytes('0x11b7f31c6c4db2bab750d5e454b10f1a480a9655c34b260b70fcf0d8d046e859'), HexBytes('0x578a7459009df2d47c5d0b5c52fc06874e64084b994c515ad053723c3871ab21'), HexBytes('0x3e0bbc8a3369eb8b01f303a918783d2502ec8acfb9cca86f2208286c5c254067'), HexBytes('0x28dfa4395cc76028b407a952172f0f365bfc1491490157fd6cce7653d3c68bfe'), HexBytes('0xcdf4c9433980f6402c9c11f97df6cbc3bf63d6b99ff875c1861b3c9b8ce3c4c4'), HexBytes('0x740bbe84a09cf7914bf63649e6b95b50ccd03b013e4905e1482beddeb53602e2'), HexBytes('0x6182570732e233f830f9294f139bff0f35b399fe04035237a676bb68a95fd710'), HexBytes('0x0aecdeccf0669dd9c2d6648006afd63194a371da08cfdea733c2f5941b9c192f'), HexBytes('0xf39b9483f3e0d40b012a0fe5df2da57cb4dec07f51ed23fd4bd5ec555954a441'), HexBytes('0x85b6d28665cc0af8679e1efccde6a68bf423275d428ce71a91811de553c42a6c'), HexBytes('0x062ac8705040cf620ec6e4edf96041295c7ec1eea461a1c405321e164521f829'), HexBytes('0xde6322b0ac089553f3fa26d540af74c3fcbdb139d7f81f5a7ac5f3c81e27f3bb'), HexBytes('0xc1dddf42f2094904fac0dfa6969a65b35706866001c44bc333488260e7307c3a'), HexBytes('0x47793d16e0a35914f169a06ec9b1fd12a69eaa7b849909f62a52941655376ca8'), HexBytes('0x7f72d9f40c9e9537580eec7d6beeae834a1a699c7614d54e2a69a9ca8130b92c'), HexBytes('0x4c38ba3c4fddffb0c7e3c19d8f2cac63341db286c8ccc93e1eeac94c9e0533fb'), HexBytes('0xb1f5869e264fed1dbc50eaed46c4c5bc6eda6eef48abfa1b0b77e0478be6f582'), HexBytes('0xf4dee1076200af67994db73fe1fadca0480c10811c11219c97d6f4084b1d7033'), HexBytes('0xf34ae29890f06a27c3e7e0ae6bc4fe97b8df789d8f012d2185ac2211a60f0b6f'), HexBytes('0xed4417086ac20f83ecccf72dc41f6ddee834376bf1eb6929928aa21e39afe0eb'), HexBytes('0xe45feddc787ee09632441343c43e74d54d2d766ff133b9eb7d7a0052ecd54283'), HexBytes('0xc5191a7a2f128b824a084197cff949a0ed0b82b975787567eb9b028fc9e49994'), HexBytes( ...
# AttributeDict({'baseFeePerGas': 108538717, 'blobGasUsed': 786432, 'difficulty': 0, 'excessBlobGas': 0, 'extraData': HexBytes('0x546974616e2028746974616e6275696c6465722e78797a29'), 'gasLimit': 44999871, 'gasUsed': 18082011, 'hash': HexBytes('0x9a82663ea90f615e03d8f6d3e53afab1f86204f23affc7f7e8484831849f206a'), 'logsBloom': HexBytes('...'), 'miner': '0x4838B106FCe9647Bdf1E7877BF73cE8B0BAD5f97', 'mixHash': HexBytes('0x91994db11eae9ab6e9c5d59c2a40917dc3ede64d8a7e4a0354765eaba0229134'), 'nonce': HexBytes('0x0000000000000000'), 'number': 23644810, 'parentBeaconBlockRoot': HexBytes('0x4361d5c8ac1fc7fbf339d00a829ad2a9c13949a8e711f951774a1927e705b03c'), 'parentHash': HexBytes('0x2845198b3ae83f7811132d0a661abf58eec3734811bfe2b368e6210abc7dbb8b'), 'receiptsRoot': HexBytes('0x149a5eb4037a90fccd13c931761e2b354ba13e5d85e084b4d75f50d44760b1f6'), 'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'size': 87986, 'stateRoot': HexBytes('0x841f0cdf844e93d1723ce012e27b65b2a651b3e0d05ae3767df6d4a759fa65f6'), 'timestamp': 1761278459, 'transactions': [HexBytes('0xb6c3d5a6c50030c7e99795428f924c88d78fcd20efa3d026b4afd7ba093ac68a'), HexBytes('0x3341e0c778de9088459a1268a8dbfe826446f189abb16f0dec750d25cc3281fc'), HexBytes('0x883d8da91556904e964daec38e0a191fedf1431bdd119f68b5b4c12485712fc7'), HexBytes('0x85a30e06e15386ea13edbdd488350e2b0fbdb4c66c3ae9a8408109e8815f61f1'), HexBytes('0xc44e8b207a1b445831d152d6225eda002f09b14b25bba8bea67c8056b3c977fb'), HexBytes('0x5e04fd6f08df95479026897f02bd49221ded1593e65f8ea50a049eef0750c91d'), HexBytes('0x7b893e18a988798b550012649cb7d0107b3cfa07bed855f09096b505839c5294'), HexBytes('0x605fa350d7e0ddecf2c534a7e468020ad4fe55f5736913cec2c09eba655dba35'), HexBytes('0x91879e3eefb56fdac4fae405d9b1310135abcc042008dc9e0ef62228ef2a4068'), HexBytes('0xd5b69daedfa6296edc83f2908dfb2d50a66fd062208348afcf213e3ca2943aa9'), HexBytes('0xb5632daefe4115cbd2de130d6392efa4ddebd8dd5438641f8e779fbdbea0abe4'), HexBytes('0xdb45cca3a8aec66494d7f1754f68b5185b0e553171bed6029903acd55260e69c'), HexBytes('0xfe9dca26a7216f864d2f1abb961a03bb200f812744e6e25f410c1e043dd83342'), HexBytes('0x2cf68ffc1be4d104300cec10474d169953bab66600616d12946f8ea2e75fee25'), HexBytes('0xb88f5b66f2432d7375b5e70b41f601a954c173711032676ea08e1afeb4ff6d26'), HexBytes('0x537bf7fb04eb0cf53bf8ccd26b18209bb53be61aed34eda449698a0c919916a4'), HexBytes('0xa5f74295df9a7cffe3501439cc367cf13b59697029551bb9764eac8400b7eb31'), HexBytes('0xdf8558d211777867051ec829807b4780754b77452c2bb256e45d65350633d2db'), HexBytes('0x87560d462fd6b8d6028b2dd275217dd1b0287ac1ff93946b212078533357dad5'), HexBytes('0xf4203a0b908f93e31eef692dbd100b115d753789c48f03c654e9bbebb68de5b1'), HexBytes('0x839689fe6407053085b85a83f1e543d16ca68efab0ef9c69ff7bab80638f10d8'), HexBytes('0xdc9106ed65006ca98763f282a575c3f06831b4886343d1299624fde99adfbd9d'), HexBytes('0x619311c7d455b2d5e2ae0ecba734783b5b3269afde2b2dd7b73d831b0422dd8f'), HexBytes('0xd1a8e0915f4cf9fc56daf729f4af7a62f795c14d59a08d1780740580f625c783'), HexBytes('0x2115d6efa96ee46eae018d350833b6738739eccf98621ebe0468c5cf3d0e75c5'), HexBytes('0x6c9f1239c88f300a95df1add411549114d570b3f2733e0b7bf3267b11f37d76c'), HexBytes('0x086b52187fc6cecdbd17d9b597e9b0b6e8dce9e6e8ec25c492da2e22fe10868c'), HexBytes('0xc0d3e5fc07b3b4978d9674baee47fd9f301a8eb7867e859e8adc9830a07afe37'), HexBytes('0xa1d22af4e6c1f38ca709be8683f565131594fa8ea8e74dd4533e7298e3e3a998'), HexBytes('0x67fa11acd6419efc5891d3afa2e47031de3a8ed7eaf017b4cf8db9947dc24f54'), HexBytes('0x3fa7882841d4da467bee1a4b67804ac561710934c2a2bf7b015591b9a275bb5d'), HexBytes('0x5257427967c911e09ff7e9b91c4dbddb6d32978a773a27c84094e94ef54e1d67'), HexBytes('0xe186369574a4f38d3ae8240ca0088b9c85779aa2abfce7d1e37721063b0d6e31'), HexBytes('0x2be6e2ef948273f81edd61f94fe2f077ca616d7d8063e7a917b38d5aee03804f'), HexBytes('0xa1d7d94f882526a27cdeb09becceb22c6a993198864c93ab00f0ab14629996fb'), HexBytes('0x28388 ...
# AttributeDict({'baseFeePerGas': 111805623, 'blobGasUsed': 393216, 'difficulty': 0, 'excessBlobGas': 262144, 'extraData': HexBytes('0xe29ca82051756173617220287175617361722e77696e2920e29ca8'), 'gasLimit': 44955970, 'gasUsed': 17223617, 'hash': HexBytes('0x2845198b3ae83f7811132d0a661abf58eec3734811bfe2b368e6210abc7dbb8b'), 'logsBloom': HexBytes('...'), 'miner': '0x396343362be2A4dA1cE0C1C210945346fb82Aa49', 'mixHash': HexBytes('0xaa15cc2ba9eb2cb090c952eff74aeaa5b3ee93f9941a618d3efaa379aded1cfc'), 'nonce': HexBytes('0x0000000000000000'), 'number': 23644809, 'parentBeaconBlockRoot': HexBytes('0x603d6abd0af396e80cd09333c2f608d28c26098407f5539efbae1b0b64979261'), 'parentHash': HexBytes('0x318ee6b58b4cd5b294bc0eb5ac31bf526f7206b56f4cb902a8de0673083dc6bf'), 'receiptsRoot': HexBytes('0xa65cff5fe1efe702189f4317f1ff4b8450a302c67770c895ff165f27c8ceb942'), 'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'size': 77887, 'stateRoot': HexBytes('0x0225fda9bdacfa4199c8638d6587a643581c2b071d7d40c4d100174d9c3b79de'), 'timestamp': 1761278447, 'transactions': [HexBytes('0x56f67b10a0b411f2149c834f5369afd1eda030ccecc955e3617452c415ce11ba'), HexBytes('0x6807f32fa99fa08afe62d10751024509f629091063514392f19f3ef1ee33ee8a'), HexBytes('0x052e8f7df598156a803b8477419202a8a05720d798ffe57c6fb076b7f0095c39'), HexBytes('0xa8f03a17c0fb82f528447d25e972e3ed9fddb1f1ae6446c0734836a5e801cfaf'), HexBytes('0x9b1d9a5fd152de54083fdca1754a54669aa38e0aa5eaa35a8939ecf17d34e48d'), HexBytes('0x8f58c4ea5446b122a272f3af7f5996e1606a5743efa5a96d98f78bcecc4dfc64'), HexBytes('0x1616e2e82fe80909c31744521527684c094b2e72332cfe7b68bfad7fecc32753'), HexBytes('0x2bdf68415a6a60abab5129646b0439485599cc5b4036f183e781399535c70a94'), HexBytes('0x649726df19eb525b969e463729f6f2af78568d8b2db21749ab2a204561f3a972'), HexBytes('0x2820ffe9e6a98251ed3ee5839013f71111874ad8490af2f685f44a5b7217407e'), HexBytes('0xbc7ef6d0975b51eaf8e5692a0f89c17c5e62497b36f55f4c1c6529fb813e7997'), HexBytes('0xcf0dd3f3378959b666424af00888ccf3952ff781a5672b8fe9339af649fcc7d5'), HexBytes('0x4d9b497bb346f600510f0f317433330a5efe8e277c291ea30777543eb122d9b9'), HexBytes('0xdbf603b2962b84b0a658a9c1b984894a659ba7f804e9e2656dcd156cb1047b18'), HexBytes('0xc694a500393e37fd558d48a65341d99393fadaeafd42bcca4c853cbc733414f7'), HexBytes('0xe77e5b7aa5a61b93506c7b1714f908191cd9e7e24abe66307670bc8cd4b87a1a'), HexBytes('0x382779fab86752588993a04ce4567d94ec2e747f9320aa2af2b27ea665a4e184'), HexBytes('0x96a30e6a6e5398a899943cea0e3ac0f89af9b992d032ae9b541b4aa4e10d5e5e'), HexBytes('0x153f07c2d8da3d7f629f35ae4ca21f3bfdef30f9abac4279f45e3c489115f595'), HexBytes('0x787a3973f58127df326b2d44ddc4febaa25989202c3c7009ed0affb730e3a533'), HexBytes('0xb977b2d8105151c304292542542787b2c3addeb23a04be5d095fa5f3046416db'), HexBytes('0xaf4eb3e28eea5b2f68b781a52300dbfa0e2511a79473dbc65725d6a424cca101'), HexBytes('0xdebdd932bd8e3f1f8f98281d09b6ea5e8cc203e7a0060c7f3932ea607e86e5be'), HexBytes('0x48bed602d937c4a35ac5d8f23f0baaa675fc5bc42d8d3dcf020854aa47474aa8'), HexBytes('0x80a436a5e36ab90f8cdce12462a84d11ba3d26d8357be45225b8c750d70f3faf'), HexBytes('0xd04c14ee930cf6aaa8a6aad11d8fc6eeb350b63b61ec3385c6af9b4b0cc7c2ab'), HexBytes('0xdab70d3ce79ef80a76000e9ef07d75553251b0af377199be94fba468277d5df0'), HexBytes('0xfe6b27c7c50795904d6acdb7c0043736780debeb34c8abeae146911173aafbf0'), HexBytes('0xe0b63e0bab61e23cdd5a0ea5b282330cc5dc5fd0ef2555e28fccf6861f71b0a2'), HexBytes('0x942e447ce393f951b218f4feefbf5b4ae520c38305713a596d48a111763e63b7'), HexBytes('0xff3a78f2f1ef625097745e8454915fa417c6eaf9e1d60e21f9157f8763b429a6'), HexBytes('0xb62338be7370978d462e9c165e3dce065aca1cceeec9c46839edbf0283bc160e'), HexBytes('0xb50fdfa2e0a0f6bffe8ea046dd150414a4ab3917b8dfdb50c36589e5b18b5d44'), HexBytes('0x70e371535e781784818000268e094e9fb85e694d80e3f35091430cea0a11737a'), HexBytes('0x452a40b49a816f5f89330960edb0ff623b6e64d17aa4f9214146094f42c72b29'), HexByt ...
# AttributeDict({'baseFeePerGas': 99778061, 'blobGasUsed': 786432, 'difficulty': 0, 'excessBlobGas': 262144, 'extraData': HexBytes('0x546974616e2028746974616e6275696c6465722e78797a29'), 'gasLimit': 44912112, 'gasUsed': 44111447, 'hash': HexBytes('0x318ee6b58b4cd5b294bc0eb5ac31bf526f7206b56f4cb902a8de0673083dc6bf'), 'logsBloom': HexBytes('...'), 'miner': '0x4838B106FCe9647Bdf1E7877BF73cE8B0BAD5f97', 'mixHash': HexBytes('0x3592e5b00556e5f4457919f107ad682fd702dbdefb9a773f37a3a5d7bd1eee79'), 'nonce': HexBytes('0x0000000000000000'), 'number': 23644808, 'parentBeaconBlockRoot': HexBytes('0xee6f07d2c6a6e1435695da66d100cded666a8227d285ae4f1e424d7dff5ce58a'), 'parentHash': HexBytes('0xdab4f808518720f64887e2f46a64e325265def400b6339a944160d4ae92d3552'), 'receiptsRoot': HexBytes('0xcf9501df8df414840fbe13c657b8e71d2e03f25ddbf47d7b6f4d31bd373c6ce7'), 'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'size': 123043, 'stateRoot': HexBytes('0x1070277ee95495b5484c8cff554ccc75167e25f6b0e875de761d07c7e1271eba'), 'timestamp': 1761278435, 'transactions': [HexBytes('0x0de1969bfbb419231bf74194fbc0b2b9df79c1724bc533ebe4862db9ababb038'), HexBytes('0xe97bc2684cfdb1f86240af064e7c80c19c44f8da12b50b9e2ebf24ece1e716ca'), HexBytes('0xb49db23bcd97b54ca24e929cf0f54ae8eadf03edf60e560f2e23dd02ef15c991'), HexBytes('0x36ca9bfcafd25e12fe707290083bcada4b45234e6077c909eb68c65e0137313d'), HexBytes('0x69a2f6725230ccb9e24b312bb7b30d9a10662db08ff4bc83589b69ed00797c30'), HexBytes('0x062db30cf5e67ef0f771017a8416557cd168dced1d45ab65e3f6fcec295058c4'), HexBytes('0x5e47cf747ea886320fed71f8d0da9374aba6999576f98da91e56bbed47684e80'), HexBytes('0x4e247c0ae3a216622f90b068754942b283a9fac8fd10fadc973e5ed7090c5041'), HexBytes('0x8a6b1f2a00f4dca5525759f636aab3a941f3c481ee7ae26b10850cf8f00c5e68'), HexBytes('0xbda7221044141ba8fbf979db4a6dbbb8e975e9c1112080a7d41db0f7987bae7b'), HexBytes('0xff46939a97172fa2906cd9abdda5d0d300d94956b6037a22845b9d9566d27490'), HexBytes('0xb2cf02e96dd6aa157939ceb907f5fba9076ad8eda089d289fa6fa2a5b4b28cb3'), HexBytes('0x2d6c9124fc7a2e95d007ee6455c0951d569b14e88b17f57dbf00ada2a17f1381'), HexBytes('0x92ca3e317b5f986578ee85b2c2ed6f2055e3a057c55a40583d6ff83ff7671768'), HexBytes('0x0bed36ae46f816547ec1902a38b05adac59e349b6924ef7da3ce8d107fdbfc1c'), HexBytes('0x5ae384333f59ea128a010b447b5ed414cd34f0ef06a2491ebf00fd0be25343f8'), HexBytes('0xbfc7c41a16776769927eaa4401cf250b4461b06093b06e7d48172e2ec6938a28'), HexBytes('0x812f0d944694e9a5840d8eb218debdee43a625f619d9d2ee7f1cba5c1bac04bd'), HexBytes('0xbbd0ebe40ea5c1e5b15782ea83fac7ef9a06a0b400fed7c7dac73f06e49e97f9'), HexBytes('0xa6c7b9c48cf835d9a7f3f3384104f194b71aceff3cd846f131076ee8dfcf9487'), HexBytes('0x2f927bf14065e139bfec7cc329e04971cb67364494c97a3a1401f4d9e3fba2e5'), HexBytes('0xfaf00eff9fe5f32896acea1509a64f7ec64e85580ab04d8aa02f2db8346e8f82'), HexBytes('0x7b9436a8cef13cc9d8300e663cee35fef5fa7083c5d5ae7c13c4eb12f50c04b4'), HexBytes('0xe66b65a97922c18442076193a0c4d51ed0aacbd4fde596ba8ab25e76e7b919d3'), HexBytes('0x01bd330a87ddff14cd27a8e9d6d13ee09abc3ca09470eb2623609f940a1be850'), HexBytes('0xb127af7e37ba63fd8ade94a31a49d7258194eaafd0c8cd58d59b7af146ac79bd'), HexBytes('0x4eb6dfb3c08b2ed28636918743dc6c4eeea187cc945ea76ebc1a72bd1786475b'), HexBytes('0xe5f51243d84d3fe1c96dd21dc2cea17864fc4d34f4fb69961fc6d6949d6263a8'), HexBytes('0xe5f155bc96ce932bc12f4047846a4f6268d7f0e918c82ef4392300aa7273cf17'), HexBytes('0xf21787bb0f83ba4bcdd3568d5ac1736690c4f7e9a25c7f8c5af57409602d2461'), HexBytes('0x45941fdf33b58fe189288add4f128270cf7474777c41eeb1acabade8219f7cb7'), HexBytes('0xa3d024269bdc47a6f6a14cd77eeadb58dfab0ef0d3433e45205cf6d03ba8db24'), HexBytes('0xffdd37b5650984ffa0d101a71a656918cc9b13fc1a363645dfb6925f09f84ea1'), HexBytes('0xeb42362530ecc6878b4bc907e7fae0a36c06646e2a10dd296bb9a720380ac282'), HexBytes('0x4d6425a7db64d8869f682a22e121045409b46124a4cb72655173eda958bc539d'), HexBytes('0x ...
# AttributeDict({'baseFeePerGas': 103672128, 'blobGasUsed': 786432, 'difficulty': 0, 'excessBlobGas': 262144, 'extraData': HexBytes('0x546974616e2028746974616e6275696c6465722e78797a29'), 'gasLimit': 44956013, 'gasUsed': 15723568, 'hash': HexBytes('0xdab4f808518720f64887e2f46a64e325265def400b6339a944160d4ae92d3552'), 'logsBloom': HexBytes('...'), 'miner': '0x4838B106FCe9647Bdf1E7877BF73cE8B0BAD5f97', 'mixHash': HexBytes('0xf038f15022a873039e61cc19ec6d52b5d9fce466384ce9218d6a249938f50d41'), 'nonce': HexBytes('0x0000000000000000'), 'number': 23644807, 'parentBeaconBlockRoot': HexBytes('0xf8ef30327494f1ea50c2419fcf69e92014b964fa64c00c79294834f0c926261f'), 'parentHash': HexBytes('0x78da79b2b780dfe5a1ae07d5f3b595175502c29d70386837e2dc076067c9c8d4'), 'receiptsRoot': HexBytes('0x8dca746c25d71502c16f5223cb5546879db59d7702e2911b76e84b0396c6b6cd'), 'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'size': 79370, 'stateRoot': HexBytes('0x8bd28756b4fc7bd910de709a9857ba988907c1bbc6c85a252c845bf119d62619'), 'timestamp': 1761278423, 'transactions': [HexBytes('0xb9fdd596493f491afc6abd1c4b663c9d0a799c35bed927867938bfd410c2f77a'), HexBytes('0xc6681e1b1b323d6b69711eb15cbefa4fcec892016b9f80e08775334e70d5dbba'), HexBytes('0x79ae9153230765c56735b7adcae04f44eab5a32843c801401301b28790feff14'), HexBytes('0x0f31ca1ca76b8e4da89c4672840a6b17563aba10bd2445e72262d972b7bc229f'), HexBytes('0xe796d3fa27e93647b8fc8dc7365c59b4c9e1dd0093b1bf96e728ceaefeeeb54a'), HexBytes('0x244440832fd9ea17ac505a433b229123f95b47f82cf539fa39ed19d57fd7d537'), HexBytes('0x2bfd29097cf1bc5a907033a3f94e5eef5ca7e073b1795a6a6633f1bb8c1ee1ea'), HexBytes('0x8960e351b324ac89e155a5163294b303665c09d92c3651db9b37e209d3b2b72d'), HexBytes('0x298ff87237b8fd3fecfa869db5f2c2b60e5a3dcce4551973235312d380383230'), HexBytes('0x1994a5429c40faebe346d8516596d095ce0f4fb6dc200d5edc69c051cdddafef'), HexBytes('0x405066d5593243bbcea586781a44d89194ac72b630da6d9dea57f08ffb447e07'), HexBytes('0x2ae4c322b701273be060f6829eac5cf762e3152be7f8ed9ee73139842cd6b58a'), HexBytes('0x9133dc5b4e63df0238dbd7516b00d7eb0bd35f726f28c2fc30a0205aaef4a968'), HexBytes('0xb688239abdf9890b93357ed98d2f2460ecd196003542c6687dc43ef097f06cd3'), HexBytes('0x300d5234a7c5098553a83ebe3a579d70ddb28a917f48ec6cbbcd3475e73ae72f'), HexBytes('0x31e6f412efbc9a235c598b9566b6ae3252307385361e0316fc47de86c530db9b'), HexBytes('0x3261f93f8ba278ccc2c1a2c9f196897c20d8fb83090a25bdcfb142a9b6bf79f5'), HexBytes('0x90361f5adbbab67b67fa22fb4cad4a7d8a4b7cf86d266323009839ceed654925'), HexBytes('0xaefbe41d1de2107ba9ad99fd1136eaac225fc4a30f092b2cd886471bac83980d'), HexBytes('0x0ae46fb98d280fca1c2a3afe7723f0deddf4d7f1d6e990dbc27b56b9fcefc4cc'), HexBytes('0xe15dfd3fdef002622cc3a95b17e84cdcc0e59d57575c382d04881a07efb316d5'), HexBytes('0x55e64e33523700fa03d464af1165590fd7180fbe9a89089bcbcc0848b5dc8b53'), HexBytes('0xc38b754fa209656652d9575950677c34266309b2cd7c7db572b6708e501fac3a'), HexBytes('0xd7170174febf1e6b42bac382f2506d9e810832177c8e1f2832c4f9a724a2475f'), HexBytes('0xb9d3e775eda75e5336e76d6ddcf359336d4ad4a101a49669260aeb5a88e2e42c'), HexBytes('0x880acd5c00110abf698621f0a701153ff67ea9c7e0b8007287d288a28f2acab5'), HexBytes('0x9e7249c3a7ecb50f34eec606e2c10ccb445c5fa40981d9607a3d24a9d00ee677'), HexBytes('0x2185841eaa2698cdc835e838bc9ebc0b3df7906cf653c01ee85e0ed515af5e5e'), HexBytes('0x6ebee48f3af0a1fdd81fe24a3f309daa4f7c2ff4a039e6c3e2beb121fdc24d26'), HexBytes('0xd5435eca5d2fdc991f4e314d11620a2b33f8618e4776f71c96c47a7338a24919'), HexBytes('0x60ae9a0ae6f57a4a7f8822bbad15a6dd8b38c2c2ae87d1d04d37fe5d27d6016d'), HexBytes('0x9c329bddcde5d7d217b2822f1054feb601b4caeb36a006d29210f89bed063b38'), HexBytes('0xc97923beedbb12de9138ab2c25b9403396011778cb84d05ace99449a8ba4d522'), HexBytes('0x76698d98e6034aeea8e01c251e05caa0a2171c2e60e220e44d27ed8314752b26'), HexBytes('0x02c75145cd2dfe5c32cfe83d6640b200dcd7fc6564b487d90d00412966068d11'), HexBytes('0x ...
# AttributeDict({'baseFeePerGas': 101523117, 'blobGasUsed': 393216, 'difficulty': 0, 'excessBlobGas': 655360, 'extraData': HexBytes('0x4275696c6465724e6574202842656176657229'), 'gasLimit': 44912155, 'gasUsed': 26258826, 'hash': HexBytes('0x78da79b2b780dfe5a1ae07d5f3b595175502c29d70386837e2dc076067c9c8d4'), 'logsBloom': HexBytes('...'), 'miner': '0xdadB0d80178819F2319190D340ce9A924f783711', 'mixHash': HexBytes('0xb830dfc86860b026310a51bd1289335f47f08ecba2d6c3842d0bcb38eb5ce579'), 'nonce': HexBytes('0x0000000000000000'), 'number': 23644806, 'parentBeaconBlockRoot': HexBytes('0x1376057e402ef3f58c64b9841d2d3f7f9a2a1f4aebf23eaaf5c52de7efe78fc3'), 'parentHash': HexBytes('0xf1045cfb70d35ae7a72dee6f9db296324c088ad0ca2d6745fd7f2d3a699a360f'), 'receiptsRoot': HexBytes('0x896b99c94b647114517a68b3f1a186079c525961eb5e293717a170a52e93b3e5'), 'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'size': 111782, 'stateRoot': HexBytes('0xf55c42d0af8ab175ab9a49d5432f92252f118bfe32a2dc271091164dbf98d082'), 'timestamp': 1761278411, 'transactions': [HexBytes('0xc9a9a96e18591b2e95b29b82bf5faeaa9aa062935d473b80377a07cbbf1a202c'), HexBytes('0x6097e01599362602e2f915c0df5ca350a43fd3a85eeb63d4fa944490071219ef'), HexBytes('0xd19c06ca96727754339e13638ac1a14014a0e1a92afd324fb8f9c964d7ae52f3'), HexBytes('0x59d98b92af3d1b7aeead436cdad201fe1081566b0e3edc6ac4ee580123fd7e80'), HexBytes('0x9bba30b7e162516872ae9b79bf3d6b77048b2c9f067af412a14264c604d3d16f'), HexBytes('0xb425b90f9e8aa54c79d26b7242b77bc4145ec6c7ce11add349657274c02446ba'), HexBytes('0x6d4b1c4436d02a68981cb9876438f9dcb91daa57f78806d4b4dfbd6d6bd3159d'), HexBytes('0x86be19159b1b60f4008ebcd8eb8b5a34e4a300c7a0533fcfa959fd1043c59e6c'), HexBytes('0xf8218213d9d1c14152b8b6a7909cbdc31303523f55de1fddda035ce9ecdc08f3'), HexBytes('0x830b1d3a98116dbfca8e90a91b11da785b17de966ea5c91ea02f3adac07c73e6'), HexBytes('0x7086044577e177256f14aad3640c4938e19b56e9e4d534aa9ce9762f0fed6044'), HexBytes('0x84b16f4e9f7db04ac7a3e247c16f4a984d6c5fa3ea6661c8a09fe47ee622e810'), HexBytes('0xdee64c16e725636072c8177c3fa562061cac233af22946a65f18fb2bbd2dd105'), HexBytes('0x324e6877a4223d7bd894a86ed135b8a97f8f8c810a7f8dcbdd9a4a4e252cf408'), HexBytes('0xf930b88a219d437313848748ee0109621928bb226954dc7ad806dfe7f7bb8071'), HexBytes('0xaf93894f4cece1a67970716edb82acce857dd68349418f99453a05073bed9721'), HexBytes('0x4044f2b6bc0c57f4bb31c56e19d7592753756ade72bb4f99664c7cdc47633755'), HexBytes('0x99208c298fccc622a71816a19fb614fb62e7e41d77893d01c223b0c700de8b06'), HexBytes('0xd004628c72bcf4160266439dee118184a4bc2484ba29190e4c0315422acff623'), HexBytes('0xcb8dbecb342b67c8c7e5b88d7a48a0f9f7fe0a1fb70305dc72ee0340574d55b1'), HexBytes('0x1526c0ba148a946c7be44c94dabaf43a3c8f9b42ecd95cc651a14f137248749e'), HexBytes('0x8ad5f8f0af835b4b66b123bdf641fd676a4ca58f2f3b0ee42adff6d5585cc3ea'), HexBytes('0xfbdbab8da486e1dda70bde3df621377ed33218987bb34686db907d5213df51d9'), HexBytes('0xcb5c3d08d1d821d3f1fe253de77e6e5bb0462df0f99f1878f6539c159197c0ab'), HexBytes('0x2535f01e8212058b79bd263445e2ebc72b1a71153805bb150dba0f2975119ba1'), HexBytes('0xed2b930e0ad6bc2f4b1e534de9a51116ede27eef29068cd069e89f9fa6edde57'), HexBytes('0x4ef4e531103db3c2f9fe345d64fd31966ecffac6d3fbebeac05ae773485f4826'), HexBytes('0x4a45b9a447bdb310972ac4d36c74ae6c04082d4b51b48e0216f5a962dac1fe00'), HexBytes('0x6b1425d061d161b4886d856a3ad8c542aaff701342b1bdcc7cea99102df31ffd'), HexBytes('0xc5ff6b14a2b112d7ac444820927f81d9774f8e58578f6ad4f1de8746fbe1f0c7'), HexBytes('0xc7af78df6656179cce19d4a60bb8f0fd67fc4f2e61c7e83b83eaaf22d8986247'), HexBytes('0x6626d3b77c0d854e80b42528bf77d43605867296f4ab6fa4a3f5bc34f03c88ad'), HexBytes('0x7684ea95f83d1ce854d9ce018ea4e863756771f72720aa6ef8b3e445fbd492ec'), HexBytes('0x52b34986665ea6e30b1cab39ec7c57d64fe06ee31f8db126bd0bbaae5f1b67de'), HexBytes('0x8cacf389c58dee064eb0e2d67111300d757178ca604063bf335bea1231242346'), HexBytes('0x3f0bf75f3 ...
# AttributeDict({'baseFeePerGas': 111748490, 'blobGasUsed': 393216, 'difficulty': 0, 'excessBlobGas': 1048576, 'extraData': HexBytes('0x407273796e636275696c646572'), 'gasLimit': 44956056, 'gasUsed': 6023490, 'hash': HexBytes('0xf1045cfb70d35ae7a72dee6f9db296324c088ad0ca2d6745fd7f2d3a699a360f'), 'logsBloom': HexBytes('...'), 'miner': '0x1f9090aaE28b8a3dCeaDf281B0F12828e676c326', 'mixHash': HexBytes('0x38bb7ffdbbc74c873010df0db72c57f85b257609e2d67b84d2be4352c06c8155'), 'nonce': HexBytes('0x0000000000000000'), 'number': 23644805, 'parentBeaconBlockRoot': HexBytes('0x35341fddcd0f97a51624a321a5fd3548f66a8297def95521cfa52901a9e0d900'), 'parentHash': HexBytes('0x50152f1b3291de49bcbd86889a3250d63391912b6f427f8da3a7802c8fa3789f'), 'receiptsRoot': HexBytes('0x95ff5b40eb64565b7c5a7cd73cc719c90c4b72b72a019b474bf01f337f162dfe'), 'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'size': 30708, 'stateRoot': HexBytes('0xc15c680445ee541cba1c41ffb99a3655cb1049d14db3b6a0b78c5789ddd4b163'), 'timestamp': 1761278399, 'transactions': [HexBytes('0xe8ff5d9de2a966de535bc6d40c92ed3879b1e48a3288e492b20b2cac16d2d365'), HexBytes('0x0890b492587c0ddae9bcbef305062d5f105fa6347d3b7dc5bff5fcd3c0748f96'), HexBytes('0x45a6f77e1a6ac4f6585134f35dd81a08df59e8c50e5b3fa4891760a1c9fe93c9'), HexBytes('0x090f78a71e77823353e27f9333576c9feec63944482a3521bec549427fb78f1f'), HexBytes('0x6c16ff36d84bf330d9fa5394960e07a01ec0a59e7e1f4cca23558760d1f1c9b3'), HexBytes('0x2f6c197af8aab022ede2fbfa297ec6c176b387ef3b49a2e5fec22a4f7a7736ad'), HexBytes('0xc4c8c0c42489b2f276dcc1e90ffd2421074e98dd805a3feeec25cb9070a3b0f7'), HexBytes('0x2477f88f35584b1d75a25a742787cbe2d1158b7d0c1fb19dc04c3b638f510258'), HexBytes('0x8c93bb281a7daa75f59dccf72b051e5806203eaac25a950c277b96c5b0420166'), HexBytes('0xe777912c2c9c52ef88eeb6c935be8c370ed63dc9140406fc6ed4e6f4170b8d18'), HexBytes('0xbc155e8fcefad070966e3a3ccf0e12b188a6e0571620c2021751b3e421dfba67'), HexBytes('0x0240ab787faf7c236d5b3ff7e1785e8a6a60e859e8f3084718c6fe2a5a111f2f'), HexBytes('0x88c9bdf7f95131d2d1989fc4aa5a66d4205db2a69ce8d692f0d9d321012c3714'), HexBytes('0x49295ccd7179215255199687d336da345d871c87699e01a85384808f2d644bbe'), HexBytes('0x2093f2eca18b19f253dee12320bc6f72b12daa1e334c0a84edbdd4c86cb53668'), HexBytes('0xd2a05d36073aefa1a09f2bb6cd3be9947d582d26dc46135a73858fdbeda9129a'), HexBytes('0xbdc7d32ed92a8aab9869c7734f921ef621db77478e7816254a35781b661e2c8d'), HexBytes('0xef6f601d80c4cec32f9be457f4a43a50a5a949d23c9319ec128142a64d11d3a3'), HexBytes('0x6acf33b92a31dfb24bc849ccefd3367099ee2db8b3b8b29c55570448c6490d82'), HexBytes('0xc0c5fa52966e6d25341e7a130dbb0b19697a71b97be618413dce314126d29126'), HexBytes('0x327e898ea2e592f29e40f8761c5a47270ec1bd57a1a95a4ae95796e2b7b8a0cc'), HexBytes('0x674f22d61adb562bcb40d68541ec1c6d3b03cd9d352c290ca36bde8954437d81'), HexBytes('0x2dae67016e1015e46e9c3b38432bebe1153c00303ad702f94a43958aa748a693'), HexBytes('0x4fd93ced285ad4fc6be527b1514cc28723515955fec91596bddab7eb7fad41c6'), HexBytes('0x5ad2415e10b6726d41f990d481af78cbebfc4e35f09ef327b234c7554bcecaf2'), HexBytes('0x7f4464c38017344e2d7d83a2c0ea0f7a4721b4d05581deca1fe0ab9aa8af9e44'), HexBytes('0x73838f4e643e6c4fd8864eae7a9aa2d6693bfc4cb07bcf261271ed332d5fac37'), HexBytes('0x1fb75b185feb0aacb133307d372f57fb37bb63d177059d2135656da4c165850c'), HexBytes('0xeacbb3761a3a9ca2b5186f16e491945eeca587f9635a4260c0aa2df98f8a548f'), HexBytes('0xd24ab3bdc8bf9df205dcd02c4da60d9d4e106a8536d7b874669ee4c1d12ad4a0'), HexBytes('0x1f0ee204a4f6496d62f955875db36aad924aa4d9f9a0c2592a44c245c6ba585c'), HexBytes('0x372318014874be9aa46e432ede3eccf1b71e1062b12ccd484d2b2a52a74236a6'), HexBytes('0xb4287f0c114cc96b9ac670cf8337bb32aecef7500a1b540d4678a10dbd5a2017'), HexBytes('0x78e350c9e7a12e0b4f0926b38819efb746cf001b069e9f03fc06d36adb86e967'), HexBytes('0x2cbb779725390a3a04c5a04377db880b651053d2af4d224dc21fb20b9aff4291'), HexBytes('0x57d70117aba820d63935bf ...

# %% [markdown]
# Web3.py 还有另一个很棒的功能，可以让你检查特定区块中包含的交易。我们可以这样做：

# %%
hash = '0x66b3fd79a49dafe44507763e9b6739aa0810de2c15590ac22b5e2f0a3f502073'
web3.eth.get_transaction_by_block(hash, 2)
# Out:
# AttributeDict({'blockHash': HexBytes('0x66b3fd79a49dafe44507763e9b6739aa0810de2c15590ac22b5e2f0a3f502073'),
#  'blockNumber': 5855123,
#  'from': '0xF7848Afd92397fbA7b08915639faE4f29F16e4cf',
#  'gas': 66666,
#  'gasPrice': 66000000000,
#  'hash': HexBytes('0x2d14bc5f3ff31f312297715e73d7a04c72ae93f4466b881f2a2780b41b6e3c4f'),
#  'input': HexBytes('0xa9059cbb00000000000000000000000099fe5d6383289cdd56e54fc0baf7f67c957a88880000000000000000000000000000000000000000000001144b9d7142dc2b0000'),
#  'nonce': 1,
#  'to': '0x8912358D977e123b51EcAd1fFA0cC4A7e32FF774',
#  'transactionIndex': 2,
#  'value': 0,
#  'type': 0,
#  'chainId': 1,
#  'v': 38,
#  'r': HexBytes('0xb96c587cb0ddcb147b04a72a857431660d52ad0dcb49b136652e07beee2da66a'),
#  's': HexBytes('0x4e1d1547b99c8c338483d1ff7521e575547f5dde85b990ebe8e6cbbf21763067')})

# %% [markdown]
# 就是这样！使用 Web3.py 检查区块就是这么简单。
